# %% [markdown]
# Introduccion al problema

# %%
# %pip install gymnasium

# %% [markdown]
# ### Windows:
#
# method 1

# %%
# %pip install swig

# %%
# %pip install gymnasium[box2d]

# %% [markdown]
# method 2

# %%
# %pip install swig

# %%
# %pip install ufal.pybox2d

# %%
# %pip install pygame

# %% [markdown]
# ### Linux:

# %%
# %pip install gymnasium[box2d]

# %% [markdown]
# https://gymnasium.farama.org/environments/box2d/lunar_lander/

# %%
from lunar import LunarLanderEnv

# %% [markdown]
# Tensorflow or Torch

# %%
# import torch
import tensorflow as tf

# %%
# Initialize the environment
lunar = LunarLanderEnv()
print(type(lunar.env.observation_space))
print(type(lunar.env.action_space))
# Out:
# <class 'gymnasium.spaces.box.Box'>
# <class 'gymnasium.spaces.discrete.Discrete'>

# %% [markdown]
# El espacio de acciones es un valor del 0 al 3 que indica que acciones tomará el modulo lunar para esa iteración.
#
# en concreto son las siguientes:
#
# |value| action                        |
# |-----|-------------------------------|
# | 0   | do nothing                    |
# | 1   | fire left orientation engine  |
# | 2   | fire main engine              |
# | 3   | fire right orientation engine |

# %%
lunar.env.action_space
# Out:
# Discrete(4)

# %% [markdown]
# El espacio de observaciones son un conjunto de valores flotantes y booleanos que indica el estado del modulo lunar.
#
# en concreto son las siguientes:
#
# |value| observation                               |
# |-----|-------------------------------------------|
# | 0   | coordenada X (float)                      |
# | 1   | coordenada Y (float)                      |
# | 2   | velocidad lineal X (float)                |
# | 3   | velocidad lineal Y (float)                |
# | 4   | Angulo en radianes desde -2π a +2π (float)|
# | 5   | Velocidad angula (float)                  |
# | 6   | Contacto de la pierna Izquierda (bool)    |
# | 7   | Contacto de la pierna Derecha (bool)      |

# %%
# se muestran los valores minimos y maximos del espacio de observaciones.
lunar.env.observation_space
# Out:
# Box([ -2.5        -2.5       -10.        -10.         -6.2831855 -10.
#   -0.         -0.       ], [ 2.5        2.5       10.        10.         6.2831855 10.
#   1.         1.       ], (8,), float32)

# %%
observation_count = lunar.env.observation_space.shape[0] 
action_count = lunar.env.action_space.n

print(f"observations: {observation_count}, actions: {action_count}")
# Out:
# observations: 8, actions: 4

# %%
#valores minimos y maximos para las observaciones.
print(lunar.env.observation_space.low) 
print(lunar.env.observation_space.high)
# Out:
# [ -2.5        -2.5       -10.        -10.         -6.2831855 -10.
#   -0.         -0.       ]
# [ 2.5        2.5       10.        10.         6.2831855 10.
#   1.         1.       ]

# %% [markdown]
# Sample ofrece una combinacion aleatoria del conjunto.

# %%
print(lunar.env.action_space.sample())  # Take a random action
# Out:
# 2

# %%
print(lunar.env.observation_space.sample())  # Sample a random observation
# Out:
# [-0.6202243  -1.8391378  -2.4691675  -7.62348    -3.9997985  -5.6660433
#   0.63264304  0.22402897]

# %% [markdown]
# Running a random episode.

# %%
def test_lunar_lander(steps_to_run_before_pause, agent, episodes=1):
    """
    Test the Lunar Lander environment with a given agent.
    
    Parameters:
    steps_to_run_before_pause (int): Number of steps to run before pausing for user input.
    agent: The agent to be tested in the environment.
    
    Returns:
    None
    """
    # Initialize the environment
    lunar = LunarLanderEnv(render_mode="human")
    
    if(agent is not None):
        # Set the agent's environment
        agent.lunar = lunar
        
    for _ in range(episodes):
        counter, score = 0, 0

        while True:
            if steps_to_run_before_pause != 0 and counter % steps_to_run_before_pause == 0:
                input("Press Enter to continue...")

            if(agent is not None):
                _, reward, done, action = agent.act()
                
            else:
                # Sample a random action from the action space
                action = lunar.env.action_space.sample()
            
                # Take a step in the environment
                _, reward, done = lunar.take_action(action, verbose=True)
                
            score += reward
            
            counter += 1
            
            if done:
                print(f"Episode finished, score: {score}")
                break
        if(agent is not None):
            # Reset the agent's environment for the next episode
            agent.lunar.reset()
        else:
            # Reset the environment for the next episode
            lunar.reset()
        
    # Close the environment
    lunar.close()

# %%
test_lunar_lander(steps_to_run_before_pause=0, agent=None, episodes=1)
# Out:
# Step taken: 2, New state: [-0.0040966   1.4084889  -0.21378545 -0.04317905  0.00382991  0.03071125
#   0.          0.        ], Reward: -1.1416672528659888, Done: False
# Step taken: 0, New state: [-0.00621901  1.4069173  -0.21379027 -0.06985303  0.0053647   0.03069845
#   0.          0.        ], Reward: -0.6781342209109482, Done: False
# Step taken: 3, New state: [-0.00825529  1.4047372  -0.2029936  -0.09689116  0.00473373 -0.01262018
#   0.          0.        ], Reward: 0.24814933664845398, Done: False
# Step taken: 0, New state: [-0.01029158  1.4019572  -0.20299104 -0.12355931  0.00410384 -0.01259913
#   0.          0.        ], Reward: -0.9310725012227863, Done: False
# Step taken: 2, New state: [-1.2195492e-02  1.3997152e+00 -1.9041231e-01 -9.9648818e-02
#   4.1207909e-03  3.3912380e-04  0.0000000e+00  0.0000000e+00], Reward: 2.193767698473704, Done: False
# Step taken: 0, New state: [-1.4099503e-02  1.3968729e+00 -1.9041245e-01 -1.2632637e-01
#   4.1372585e-03  3.2934122e-04  0.0000000e+00  0.0000000e+00], Reward: -1.0787789330682074, Done: False
# Step taken: 2, New state: [-0.01616535  1.3947281  -0.20583732 -0.09531847  0.00339955 -0.0147557
#   0.          0.        ], Reward: 0.15304215541827376, Done: False
# Step taken: 1, New state: [-0.01829119  1.3919806  -0.21336374 -0.12211771  0.00417214  0.01545323
#   0.          0.        ], Reward: -1.7354556123178202, Done: False
# Step taken: 1, New state: [-0.02047997  1.3886312  -0.22126219 -0.14887002  0.00652654  0.04709273
#   0.          0.        ], Reward: -2.0178748677604674, Done: False
# Step taken: 3, New state: [-0.02260771  1.3846749  -0.21360826 -0.17584671  0.00734533  0.01637725
#   0.          0.        ], Reward: -0.719175186201851, Done: False
# Step taken: 0, New state: [-0.02473555  1.3801183  -0.2136097  -0.20251513  0.00816498  0.01639472
#   0.          0.        ], Reward: -1.3971678954778213, Done: False
# Step taken: 0, New state: [-0.02686338  1.3749619  -0.21361163 -0.22918373  0.00898419  0.01638559
#   0.          0.        ], Reward: -1.4651451475237707, Done: False
# Step taken: 0, New state: [-0.02899122  1.3692054  -0.21361415 -0.25585234  0.00980327  0.01638319
#   0.          0.        ], Reward: -1.5113707220766912, Done: False
# Step taken: 1, New state: [-0.03119335  1.3628395  -0.2229383  -0.28295085  0.01249201  0.05377962
#   0.          0.        ], Reward: -2.3594904701187986, Done: False
# Step taken: 2, New state: [-0.03339805  1.3567216  -0.22321706 -0.27192247  0.01520092  0.0541832
#   0.          0.        ], Reward: 0.8774280965397565, Done: False
# Step taken: 2, New state: [-0.03574762  1.3505853  -0.23703738 -0.2727518   0.0172579   0.04114348
#   0.          0.        ], Reward: -0.8535254698826578, Done: False
# Step taken: 3, New state: [-0.03803759  1.3438585  -0.2295613  -0.29897705  0.01781331  0.01110923
#   0.          0.        ], Reward: -0.9777398201673566, Done: False
#   0.          0.        ], Reward: -1.2823860668241196, Done: False
# Step taken: 1, New state: [-0.19429255  0.30936113 -0.41292375 -1.2876555   0.6865575   0.3542968
#   0.          0.        ], Reward: -2.8176146128339483, Done: False
# Step taken: 1, New state: [-0.19835778  0.27987507 -0.42236286 -1.3193104   0.7069269   0.40738875
#   0.          0.        ], Reward: -3.1420552765343346, Done: False
# Step taken: 3, New state: [-0.20235495  0.24987231 -0.41338438 -1.3413731   0.72479814  0.3574248
#   0.          0.        ], Reward: -1.5023297981219617, Done: False
# Step taken: 1, New state: [-0.206425    0.21919249 -0.42234936 -1.3727753   0.7451972   0.40798116
#   0.          0.        ], Reward: -3.29079681788417, Done: False
# Step taken: 1, New state: [-0.21054454  0.18784963 -0.42839512 -1.4033313   0.7674801   0.44565815
#   0.          0.        ], Reward: -3.4640774967604373, Done: False
# Step taken: 1, New state: [-0.21473221  0.15581103 -0.43680653 -1.4358041   0.7924953   0.50030553
#   0.          0.        ], Reward: -4.197130075108986, Done: False
# Step taken: 2, New state: [-0.21949343  0.12434586 -0.49420786 -1.4109674   0.81822336  0.51456076
#   0.          0.        ], Reward: -0.9928362228184142, Done: False
# Step taken: 0, New state: [-0.22425894  0.09228659 -0.49414787 -1.4376724   0.8439502   0.5145372
#   0.          0.        ], Reward: -4.117391907982324, Done: False
# Step taken: 3, New state: [-0.22896639  0.05972379 -0.4861599  -1.4590405   0.8671158   0.46331257
#   0.          1.        ], Reward: 6.473277285510307, Done: False
# Step taken: 3, New state: [-0.23361698  0.02734195 -0.47964436 -1.4648935   0.89140207  0.4612618
#   0.          1.        ], Reward: -2.668439262066754, Done: False
# Step taken: 0, New state: [-0.23719493  0.01296102 -0.44622096 -0.30931452  1.0886905   5.0311193
#   0.          1.        ], Reward: -100, Done: True
# Episode finished, score: -202.16218149686466
# Environment closed.

# %% [markdown]
# DQN

# %%
from DQN import DQNAgent
lunar = LunarLanderEnv(render_mode=None)

# %% [markdown]
# Train

# %%
agent = DQNAgent(lunar)
agent.train()
# Out:
# QNetwork:
#  <DQN name=dqn, built=False>
# c:\Users\nikol\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 agent = DQNAgent(lunar)
# ----> 2 agent.train()
#
# File c:\Users\nikol\Documents\444_US\IA\Propuesta (1)\prueba\IA-2025-Modulo-lunar\DQN.py:221, in DQNAgent.train(self)
#     218 while not done:
#     219     # Select and take action (aquí es donde necesitas pasar el state)
#     220     action = self.act()
# --> 221     next_state, reward, done, _ = self.lunar.take_action()
#     223     # Store experience
#     224     self.memory.push(state, action, reward, next_state, done)
#
# TypeError: LunarLanderEnv.take_action() missing 1 required positional argument: 'action'

# %% [markdown]
# Test

# %%
# agent with epsilon = 0.0 (no exploration)
agent = DQNAgent(lunar, epsilon=0.0)
agent.load_model("modelo_DQN.h5")

# %%
test_lunar_lander(steps_to_run_before_pause=25, agent=agent, episodes=1)

# %% [markdown]
# REINFORCE

# %%
from REINFORCE import REINFORCEAgent
lunar = LunarLanderEnv(render_mode=None)

# %%
# agent = REINFORCEAgent(lunar, episodes=5000)
# agent.load_model("modelo_REINFORCE.h5")

# %%
agent = REINFORCEAgent(lunar)
agent.load_model("modelo_REINFORCE.h5")

# %%
test_lunar_lander(steps_to_run_before_pause=75, agent=agent, episodes=1)
