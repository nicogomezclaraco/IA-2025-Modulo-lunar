# %% [markdown]
# Introduccion al problema

# %%
# %pip install gymnasium

# %% [markdown]
# ### Windows:
#
# method 1

# %%
# %pip install swig

# %%
# %pip install gymnasium[box2d]

# %% [markdown]
# method 2

# %%
# %pip install swig

# %%
# %pip install ufal.pybox2d

# %%
# %pip install pygame

# %% [markdown]
# ### Linux:

# %%
# %pip install gymnasium[box2d]

# %% [markdown]
# https://gymnasium.farama.org/environments/box2d/lunar_lander/

# %%
from lunar import LunarLanderEnv

# %% [markdown]
# Tensorflow or Torch

# %%
# import torch
import tensorflow as tf

# %%
# Initialize the environment
lunar = LunarLanderEnv()
print(type(lunar.env.observation_space))
print(type(lunar.env.action_space))
# Out:
# <class 'gymnasium.spaces.box.Box'>
# <class 'gymnasium.spaces.discrete.Discrete'>

# %% [markdown]
# El espacio de acciones es un valor del 0 al 3 que indica que acciones tomará el modulo lunar para esa iteración.
#
# en concreto son las siguientes:
#
# |value| action                        |
# |-----|-------------------------------|
# | 0   | do nothing                    |
# | 1   | fire left orientation engine  |
# | 2   | fire main engine              |
# | 3   | fire right orientation engine |

# %%
lunar.env.action_space
# Out:
# Discrete(4)

# %% [markdown]
# El espacio de observaciones son un conjunto de valores flotantes y booleanos que indica el estado del modulo lunar.
#
# en concreto son las siguientes:
#
# |value| observation                               |
# |-----|-------------------------------------------|
# | 0   | coordenada X (float)                      |
# | 1   | coordenada Y (float)                      |
# | 2   | velocidad lineal X (float)                |
# | 3   | velocidad lineal Y (float)                |
# | 4   | Angulo en radianes desde -2π a +2π (float)|
# | 5   | Velocidad angula (float)                  |
# | 6   | Contacto de la pierna Izquierda (bool)    |
# | 7   | Contacto de la pierna Derecha (bool)      |

# %%
# se muestran los valores minimos y maximos del espacio de observaciones.
lunar.env.observation_space
# Out:
# Box([ -2.5        -2.5       -10.        -10.         -6.2831855 -10.
#   -0.         -0.       ], [ 2.5        2.5       10.        10.         6.2831855 10.
#   1.         1.       ], (8,), float32)

# %%
observation_count = lunar.env.observation_space.shape[0] 
action_count = lunar.env.action_space.n

print(f"observations: {observation_count}, actions: {action_count}")
# Out:
# observations: 8, actions: 4

# %%
#valores minimos y maximos para las observaciones.
print(lunar.env.observation_space.low) 
print(lunar.env.observation_space.high)
# Out:
# [ -2.5        -2.5       -10.        -10.         -6.2831855 -10.
#   -0.         -0.       ]
# [ 2.5        2.5       10.        10.         6.2831855 10.
#   1.         1.       ]

# %% [markdown]
# Sample ofrece una combinacion aleatoria del conjunto.

# %%
print(lunar.env.action_space.sample())  # Take a random action
# Out:
# 3

# %%
print(lunar.env.observation_space.sample())  # Sample a random observation
# Out:
# [ 1.3023962  -0.17677674  7.263743   -7.1705165  -1.3551079  -6.758819
#   0.82272685  0.6325608 ]

# %% [markdown]
# Running a random episode.

# %%
def test_lunar_lander(steps_to_run_before_pause, agent, episodes=1):
    """
    Test the Lunar Lander environment with a given agent.
    
    Parameters:
    steps_to_run_before_pause (int): Number of steps to run before pausing for user input.
    agent: The agent to be tested in the environment.
    
    Returns:
    None
    """
    # Initialize the environment
    lunar = LunarLanderEnv(render_mode="human")
    
    if(agent is not None):
        # Set the agent's environment
        agent.lunar = lunar
        
    for _ in range(episodes):
        counter, score = 0, 0

        while True:
            if steps_to_run_before_pause != 0 and counter % steps_to_run_before_pause == 0:
                input("Press Enter to continue...")

            if(agent is not None):
                _, reward, done, action = agent.act()
                
            else:
                # Sample a random action from the action space
                action = lunar.env.action_space.sample()
            
                # Take a step in the environment
                _, reward, done = lunar.take_action(action, verbose=True)
                
            score += reward
            
            counter += 1
            
            if done:
                print(f"Episode finished, score: {score}")
                break
        if(agent is not None):
            # Reset the agent's environment for the next episode
            agent.lunar.reset()
        else:
            # Reset the environment for the next episode
            lunar.reset()
        
    # Close the environment
    lunar.close()

# %%
test_lunar_lander(steps_to_run_before_pause=0, agent=None, episodes=1)
# Out:
# Step taken: 2, New state: [ 0.00818291  1.4125452   0.41884542  0.05065892 -0.00872376 -0.0810965
#   0.          0.        ], Reward: -2.081332902933485, Done: False
# Step taken: 2, New state: [ 0.01216831  1.4141816   0.40345174  0.07269114 -0.01358561 -0.09724595
#   0.          0.        ], Reward: 0.24230794303640552, Done: False
# Step taken: 3, New state: [ 0.01624002  1.4152222   0.41428772  0.04617164 -0.02061497 -0.1406001
#   0.          0.        ], Reward: -1.5315455354729284, Done: False
# Step taken: 0, New state: [ 0.02031212  1.4156636   0.41430965  0.01950446 -0.0276426  -0.14056541
#   0.          0.        ], Reward: -0.5437478470747408, Done: False
# Step taken: 2, New state: [ 0.02453508  1.4169436   0.4288035   0.05675288 -0.03407544 -0.12866887
#   0.          0.        ], Reward: -2.855376715792363, Done: False
# Step taken: 2, New state: [ 0.0287426   1.4185075   0.42742926  0.06933594 -0.04067776 -0.13205896
#   0.          0.        ], Reward: -1.1718646643513921, Done: False
# Step taken: 3, New state: [ 0.03302431  1.4194744   0.4367183   0.04271901 -0.04913477 -0.16915572
#   0.          0.        ], Reward: -1.560308782102935, Done: False
# Step taken: 1, New state: [ 0.03722811  1.4198544   0.42691857  0.01666699 -0.05561082 -0.12953293
#   0.          0.        ], Reward: 0.4298920038769165, Done: False
# Step taken: 2, New state: [ 0.04132586  1.4208754   0.41704732  0.04508665 -0.06280839 -0.14396454
#   0.          0.        ], Reward: -0.3564997049311273, Done: False
# Step taken: 1, New state: [ 0.04536314  1.4213092   0.40942973  0.01902778 -0.06846086 -0.11306007
#   0.          0.        ], Reward: 0.3096493913075744, Done: False
# Step taken: 1, New state: [ 0.04932413  1.4211423   0.39987022 -0.00759168 -0.07219733 -0.07473607
#   0.          0.        ], Reward: 0.5927868908678999, Done: False
# Step taken: 0, New state: [ 0.05328522  1.4203757   0.3998802  -0.03426154 -0.07593371 -0.07473446
#   0.          0.        ], Reward: -0.4516197196315943, Done: False
# Step taken: 1, New state: [ 0.05714998  1.4190226   0.3877737  -0.06020331 -0.07722658 -0.02585953
#   0.          0.        ], Reward: 0.8535045944622095, Done: False
# Step taken: 2, New state: [ 0.06126642  1.4185151   0.41210884 -0.0225806  -0.07768761 -0.00922132
#   0.          0.        ], Reward: -2.343332877656155, Done: False
# Step taken: 2, New state: [ 0.0655055   1.4184514   0.42405313 -0.00283407 -0.07782706 -0.00278966
#   0.          0.        ], Reward: -1.4600696270313904, Done: False
# Step taken: 0, New state: [ 0.06974459  1.4177877   0.4240531  -0.02950532 -0.07796641 -0.00278747
#   0.          0.        ], Reward: -0.06939846276094386, Done: False
# Step taken: 0, New state: [ 0.07398367  1.416524    0.42405373 -0.05616991 -0.07810561 -0.00278457
#   0.          0.        ], Reward: -0.177126661052597, Done: False
# Step taken: 0, New state: [ 0.07822285  1.4146605   0.42405367 -0.08283843 -0.07824481 -0.00278414
#   0.          0.        ], Reward: -0.2817248610408285, Done: False
# Step taken: 3, New state: [ 0.08253326  1.4121873   0.43300828 -0.11001502 -0.08018775 -0.03886212
#   0.          0.        ], Reward: -1.4715048710783083, Done: False
# Step taken: 3, New state: [ 0.0869359   1.4090946   0.44458437 -0.13768835 -0.08447092 -0.08567124
#   0.          0.        ], Reward: -2.0411766824652475, Done: False
# Step taken: 2, New state: [ 0.09128456  1.4064267   0.43970132 -0.11885749 -0.08927234 -0.09603695
#   0.          0.        ], Reward: 0.4521270502276707, Done: False
# Step taken: 0, New state: [ 0.09563341  1.4031587   0.4397134  -0.14553684 -0.09407301 -0.0960222
#   0.          0.        ], Reward: -0.9518585141404685, Done: False
# Step taken: 3, New state: [ 0.10007229  1.3992742   0.45103496 -0.17310381 -0.10116048 -0.14176224
#   0.          0.        ], Reward: -2.376144544281003, Done: False
# Step taken: 1, New state: [ 0.10443716  1.3948123   0.4416946  -0.19867015 -0.10633818 -0.1035632
#   0.          0.        ], Reward: -0.25520639921307864, Done: False
# Step taken: 2, New state: [ 0.10877609  1.3906655   0.439528   -0.18471247 -0.11193512 -0.11193871
#   0.          0.        ], Reward: 0.2760966310259619, Done: False
# Step taken: 0, New state: [ 0.11311503  1.3859193   0.43952757 -0.21138173 -0.11753206 -0.11193855
#   0.          0.        ], Reward: -1.2163567835230253, Done: False
# Step taken: 3, New state: [ 0.11752997  1.3805597   0.44905978 -0.23881462 -0.1250587  -0.15053289
#   0.          0.        ], Reward: -2.3749534682419537, Done: False
# Step taken: 0, New state: [ 0.1219449   1.3746011   0.44905892 -0.26548597 -0.13258532 -0.15053234
#   0.          0.        ], Reward: -1.5026984397259753, Done: False
# Step taken: 3, New state: [ 0.12643489  1.3680176   0.45849523 -0.29347745 -0.14205134 -0.1893208
#   0.          0.        ], Reward: -2.6324612086806654, Done: False
# Step taken: 0, New state: [ 0.13092498  1.3608353   0.4584937  -0.32015154 -0.15151732 -0.1893194
#   0.          0.        ], Reward: -1.7567395779855985, Done: False
# Step taken: 3, New state: [ 0.13550463  1.3530447   0.4696905  -0.3474813  -0.16323748 -0.23440298
#   0.          0.        ], Reward: -2.976016133121844, Done: False
# Step taken: 0, New state: [ 0.14008446  1.3446559   0.4696878  -0.37415934 -0.17495751 -0.23440102
#   0.          0.        ], Reward: -2.0087685373179625, Done: False
# Step taken: 2, New state: [ 0.14468288  1.3366551   0.47196126 -0.3570646  -0.18712285 -0.24330673
#   0.          0.        ], Reward: 0.09933468986049548, Done: False
# Step taken: 0, New state: [ 0.1492815   1.3280562   0.47195786 -0.38374344 -0.19928807 -0.24330421
#   0.          0.        ], Reward: -2.0588386077386076, Done: False
# Step taken: 2, New state: [ 0.15389042  1.3194253   0.4732503  -0.38530597 -0.21175317 -0.24930248
#   0.          0.        ], Reward: -0.9403324333046783, Done: False
# Step taken: 3, New state: [ 0.15855789  1.3101674   0.48063523 -0.41352126 -0.22578701 -0.2806769
#   0.          0.        ], Reward: -2.946628214514418, Done: False
# Step taken: 0, New state: [ 0.16322593  1.3003119   0.48062983 -0.44020405 -0.23982069 -0.28067312
#   0.          0.        ], Reward: -2.2535735494633116, Done: False
# Step taken: 2, New state: [ 0.16818532  1.2906061   0.50898814 -0.43354744 -0.25309297 -0.26544583
#   0.          0.        ], Reward: -2.4123962719862844, Done: False
# Step taken: 3, New state: [ 0.17323427  1.2802627   0.5202307  -0.46243227 -0.26875457 -0.31323192
#   0.          0.        ], Reward: -3.38166870392473, Done: False
# Step taken: 1, New state: [ 0.17819205  1.269357    0.50867337 -0.48712173 -0.2819857  -0.2646227
#   0.          0.        ], Reward: -1.1654280601936182, Done: False
# Step taken: 2, New state: [ 0.18345451  1.2585682   0.5383852  -0.48189437 -0.29447725 -0.24983108
#   0.          0.        ], Reward: -2.381003420617975, Done: False
# Step taken: 3, New state: [ 0.18879604  1.2471544   0.548236   -0.51019937 -0.3090357  -0.29116893
#   0.          0.        ], Reward: -3.0711874341025394, Done: False
# Step taken: 0, New state: [ 0.19413805  1.2351432   0.548228   -0.536883   -0.32359388 -0.29116467
#   0.          0.        ], Reward: -2.192332016382096, Done: False
# Step taken: 3, New state: [ 0.19957313  1.2224957   0.55982846 -0.56586236 -0.34063172 -0.34075674
#   0.          0.        ], Reward: -3.437303414384529, Done: False
# Step taken: 3, New state: [ 0.20508146  1.2092245   0.56888455 -0.5942117  -0.35959008 -0.37916726
#   0.          0.        ], Reward: -3.3704668662466006, Done: False
# Step taken: 1, New state: [ 0.21052599  1.1953969   0.56063586 -0.61871755 -0.3767135  -0.34246835
#   0.          0.        ], Reward: -1.7036461801530993, Done: False
# Step taken: 3, New state: [ 0.21604824  1.1809202   0.57038456 -0.648311   -0.3960583  -0.38689587
#   0.          0.        ], Reward: -3.4939977505059674, Done: False
# Step taken: 1, New state: [ 0.22150345  1.1658978   0.56167746 -0.6722604  -0.41339663 -0.34676683
#   0.          0.        ], Reward: -1.6385195204084357, Done: False
# Step taken: 1, New state: [ 0.22688207  1.1503301   0.55183035 -0.6960587  -0.4284926  -0.30191928
#   0.          0.        ], Reward: -1.3376473522803554, Done: False
# Step taken: 0, New state: [ 0.23226157  1.1341652   0.55181855 -0.72274274 -0.44358832 -0.3019145
#   0.          0.        ], Reward: -2.1361767715552276, Done: False
# Step taken: 3, New state: [ 0.23771372  1.1173525   0.5609158  -0.75229186 -0.4607961  -0.34415525
#   0.          0.        ], Reward: -3.1231859188129634, Done: False
# Step taken: 0, New state: [ 0.2431672   1.0999434   0.56089956 -0.7789808  -0.4780035  -0.34414822
#   0.          0.        ], Reward: -2.286908794175247, Done: False
# Step taken: 2, New state: [ 0.24896412  1.0827389   0.5948679  -0.76998466 -0.49494058 -0.3387413
#   0.          0.        ], Reward: -1.7530877279773336, Done: False
# Step taken: 1, New state: [ 0.25467825  1.064996    0.58426404 -0.79326564 -0.50940055 -0.28919932
#   0.          0.        ], Reward: -1.0990716847933004, Done: False
# Step taken: 0, New state: [ 0.26039344  1.0466557   0.58425134 -0.8199476  -0.52386034 -0.28919518
#   0.          0.        ], Reward: -1.9596905480593705, Done: False
# Step taken: 0, New state: [ 0.26610938  1.0277175   0.58423835 -0.8466295  -0.5383199  -0.289191
#   0.          0.        ], Reward: -1.9348807084306259, Done: False
# Step taken: 0, New state: [ 0.27182636  1.0081818   0.584225   -0.8733112  -0.5527792  -0.2891868
#   0.          0.        ], Reward: -1.9094809702191924, Done: False
# Step taken: 0, New state: [ 0.2775444   0.98804855  0.58421135 -0.8999929  -0.56723833 -0.28918263
#   0.          0.        ], Reward: -1.88369135575482, Done: False
# Step taken: 0, New state: [ 0.2832635   0.96731776  0.5841974  -0.9266743  -0.5816972  -0.28917846
#   0.          0.        ], Reward: -1.8577134640931376, Done: False
# Step taken: 2, New state: [ 0.28954735  0.94685     0.63995963 -0.9148226  -0.5954349  -0.27475217
#   0.          0.        ], Reward: -1.992496538734929, Done: False
# Step taken: 1, New state: [ 0.29577512  0.92584765  0.6326112  -0.93792444 -0.60719794 -0.23526123
#   0.          0.        ], Reward: -0.8756948932700925, Done: False
# Step taken: 0, New state: [ 0.30200368  0.90424675  0.6326014  -0.96460056 -0.6189609  -0.23525897
#   0.          0.        ], Reward: -1.5370884256360569, Done: False
# Step taken: 3, New state: [ 0.3083109   0.8819711   0.64248693 -0.99570197 -0.6333074  -0.28692907
#   0.          0.        ], Reward: -2.706839532457279, Done: False
# Step taken: 2, New state: [ 0.31522894  0.860271    0.70335793 -0.97018135 -0.64751995 -0.2842505
#   0.          0.        ], Reward: -1.2435914794015617, Done: False
# Step taken: 1, New state: [ 0.32207996  0.83805126  0.6945988  -0.9923813  -0.6593149  -0.23589826
#   0.          0.        ], Reward: -0.6698747733714459, Done: False
# Step taken: 0, New state: [ 0.32893172  0.81523293  0.6945881  -1.0190572  -0.6711097  -0.23589599
#   0.          0.        ], Reward: -1.5017478835582097, Done: False
# Step taken: 0, New state: [ 0.33578435  0.791816    0.69457734 -1.045733   -0.68290436 -0.23589373
#   0.          0.        ], Reward: -1.4902200319717736, Done: False
# Step taken: 0, New state: [ 0.34263772  0.76780057  0.69456637 -1.0724088  -0.6946989  -0.23589143
#   0.          0.        ], Reward: -1.480717451608939, Done: False
# Step taken: 1, New state: [ 0.34943572  0.74325     0.68741167 -1.0953988  -0.70450354 -0.1960916
#   0.          0.        ], Reward: -0.615484650471642, Done: False
# Step taken: 2, New state: [ 0.35643655  0.7188229   0.7081904  -1.0902816  -0.7150378  -0.21068554
#   0.          0.        ], Reward: -0.14506685661341406, Done: False
# Step taken: 3, New state: [ 0.36348695  0.69373614  0.7144544  -1.1204718  -0.7273913  -0.24706903
#   0.          0.        ], Reward: -2.2282273866158264, Done: False
# Step taken: 1, New state: [ 0.37047395  0.66814643  0.70603335 -1.1417103  -0.73712105 -0.19459505
#   0.          0.        ], Reward: -0.43272746796478034, Done: False
# Step taken: 1, New state: [ 0.37741166  0.6420363   0.6994752  -1.1639295  -0.74474865 -0.15255256
#   0.          0.        ], Reward: -0.4250778495168379, Done: False
# Step taken: 2, New state: [ 0.38466758  0.61599725  0.73149335 -1.1609405  -0.7526965  -0.15895702
#   0.          0.        ], Reward: -0.66743652458307, Done: False
# Step taken: 2, New state: [ 0.3923726   0.58990735  0.77609026 -1.1630731  -0.76028514 -0.15177307
#   0.          0.        ], Reward: -1.8890028081959145, Done: False
# Step taken: 2, New state: [ 0.4005642   0.56405896  0.82482547 -1.1524287  -0.768031   -0.15491779
#   0.          0.        ], Reward: -1.3040878752256504, Done: False
# Step taken: 2, New state: [ 0.409223    0.5384787   0.8717209  -1.1406921  -0.7760815  -0.16100916
#   0.          0.        ], Reward: -1.40155709783578, Done: False
# Step taken: 3, New state: [ 0.41793022  0.5122222   0.8780106  -1.1717628  -0.78619576 -0.20228544
#   0.          0.        ], Reward: -2.374385101014609, Done: False
# Step taken: 3, New state: [ 0.42668715  0.48529494  0.8843209  -1.2025886  -0.79831386 -0.24236193
#   0.          0.        ], Reward: -2.604233281474562, Done: False
# Step taken: 0, New state: [ 0.435445    0.45776913  0.88430774 -1.2292637  -0.81043184 -0.24235952
#   0.          0.        ], Reward: -1.9279115042683088, Done: False
# Step taken: 1, New state: [ 0.4441492   0.42974746  0.8770491  -1.250082   -0.81994665 -0.19029605
#   0.          0.        ], Reward: -0.8809520490376872, Done: False
# Step taken: 3, New state: [ 0.4529168  0.4010369  0.8850455 -1.2820114 -0.8320062 -0.2411916
#   0.         0.       ], Reward: -3.006246986717683, Done: False
# Step taken: 0, New state: [ 0.46168527  0.37172765  0.8850323  -1.3086861  -0.84406567 -0.24118915
#   0.          0.        ], Reward: -2.1861714838521493, Done: False
# Step taken: 2, New state: [ 0.47096902  0.34276786  0.93684083 -1.2935269  -0.8567293  -0.25327283
#   0.          0.        ], Reward: -2.2717983616869786, Done: False
# Step taken: 2, New state: [ 0.4805234   0.31359988  0.9638518  -1.3028979  -0.8694855  -0.2551234
#   0.          0.        ], Reward: -3.057741994685432, Done: False
# Step taken: 3, New state: [ 0.4901201   0.28376698  0.9691135  -1.3334562  -0.8840433  -0.29115543
#   0.          0.        ], Reward: -3.515205215325152, Done: False
# Step taken: 3, New state: [ 0.49977845  0.25322658  0.976906   -1.3665042  -0.9014527  -0.34818935
#   0.          0.        ], Reward: -4.300484480419953, Done: False
# Step taken: 2, New state: [ 0.5103173  0.2229531  1.0644538 -1.3545309 -0.9184307 -0.3395598
#   0.         0.       ], Reward: -5.955273688630075, Done: False
# Step taken: 1, New state: [ 0.52081585  0.19215582  1.059005   -1.3768705  -0.9334469  -0.30032387
#   1.          0.        ], Reward: 7.215311026374679, Done: False
# Step taken: 2, New state: [ 0.5301954   0.18468326  0.99586356 -0.40551606 -1.0178554  -1.6400301
#   1.          0.        ], Reward: 56.80503326964522, Done: False
# Step taken: 1, New state: [ 0.5396115   0.17829981  0.9753418  -0.32291144 -1.0849032  -1.341104
#   1.          0.        ], Reward: -2.6357982008096017, Done: False
# Step taken: 2, New state: [ 0.54986894  0.17306049  1.0490694  -0.2642152  -1.1364565  -1.0307097
#   1.          0.        ], Reward: -11.713112091557537, Done: False
# Step taken: 3, New state: [ 0.5602832   0.17126621  1.0373714  -0.0739933  -1.1270018   0.18915261
#   1.          0.        ], Reward: 4.156266738242523, Done: False
# Step taken: 1, New state: [ 0.5693523  0.1742474  0.9302429  0.0771924 -1.1525495 -0.4369866
#   0.         0.       ], Reward: -2.8825449753956307, Done: False
# Step taken: 0, New state: [ 0.57803786  0.1775272   0.8908536   0.08702341 -1.1996695  -0.889501
#   1.          0.        ], Reward: 8.196087004133403, Done: False
# Step taken: 2, New state: [ 0.5873314   0.18070036  0.9555712   0.08199523 -1.2489356  -0.9325253
#   1.          0.        ], Reward: -12.607045038684749, Done: False
# Step taken: 0, New state: [ 0.5966813   0.18339652  0.9486662   0.06157467 -1.3024657  -1.0287066
#   1.          0.        ], Reward: -5.483924546323237, Done: False
# Step taken: 2, New state: [ 0.6065537   0.18575472  0.99776345  0.0544893  -1.3582635  -1.0917228
#   1.          0.        ], Reward: -11.751544348972107, Done: False
# Step taken: 2, New state: [ 0.61684287  0.18729244  1.038597    0.02956408 -1.4128346  -1.0872761
#   1.          0.        ], Reward: -10.762896119656649, Done: False
# Step taken: 1, New state: [ 0.6271561   0.18843521  1.0359607   0.00992835 -1.4661875  -1.0593008
#   1.          0.        ], Reward: -6.0846516075642105, Done: False
# Step taken: 1, New state: [ 0.6374275   0.18905713  1.0314391  -0.00807537 -1.5190489  -1.057625
#   1.          0.        ], Reward: -5.864409718477559, Done: False
# Step taken: 1, New state: [ 0.64768374  0.18925525  1.0270793  -0.02721979 -1.5724657  -1.0687182
#   1.          0.        ], Reward: -5.95805960792424, Done: False
# Step taken: 0, New state: [ 0.65794563  0.18891822  1.0246768  -0.05228075 -1.6277639  -1.106306
#   1.          0.        ], Reward: -6.3630922741127165, Done: False
# Step taken: 0, New state: [ 0.66687584  0.19151095  0.6764538   0.28081042 -1.6842867  -0.9118233
#   1.          0.        ], Reward: -100, Done: True
# Episode finished, score: -251.34271623224916
# Environment closed.

# %% [markdown]
# DQN

# %%
from DQN import DQNAgent
lunar = LunarLanderEnv(render_mode=None)

# %% [markdown]
# Train

# %%
agent = DQNAgent(lunar)
agent.train()
# Out:
# QNetwork:
#  <DQN name=dqn, built=True>
# Iniciando entrenamiento DQN optimizado...
# Episode: 1/1500, Total Reward: -82.49, Avg Reward (last 100): -82.49, Epsilon: 1.000
# Ep: 1/1500 | Reward: -82.5 | Avg: -82.5 | ε: 1.000 | Loss: 0.0000 | Time: 0.0min
# Episode: 2/1500, Total Reward: -310.79, Avg Reward (last 100): -196.64, Epsilon: 0.998
# Ep: 2/1500 | Reward: -310.8 | Avg: -196.6 | ε: 0.998 | Loss: 0.0000 | Time: 0.0min
# Episode: 3/1500, Total Reward: -189.52, Avg Reward (last 100): -194.27, Epsilon: 0.996
# Ep: 3/1500 | Reward: -189.5 | Avg: -194.3 | ε: 0.996 | Loss: 0.0000 | Time: 0.0min
# Episode: 4/1500, Total Reward: -174.22, Avg Reward (last 100): -189.26, Epsilon: 0.994
# Ep: 4/1500 | Reward: -174.2 | Avg: -189.3 | ε: 0.994 | Loss: 0.0000 | Time: 0.0min
# Episode: 5/1500, Total Reward: -111.86, Avg Reward (last 100): -173.78, Epsilon: 0.992
# Ep: 5/1500 | Reward: -111.9 | Avg: -173.8 | ε: 0.992 | Loss: 0.0000 | Time: 0.0min
# Episode: 6/1500, Total Reward: -194.64, Avg Reward (last 100): -177.25, Epsilon: 0.990
# Ep: 6/1500 | Reward: -194.6 | Avg: -177.3 | ε: 0.990 | Loss: 0.0000 | Time: 0.0min
# Episode: 7/1500, Total Reward: -97.59, Avg Reward (last 100): -165.87, Epsilon: 0.988
# Ep: 7/1500 | Reward: -97.6 | Avg: -165.9 | ε: 0.988 | Loss: 0.0000 | Time: 0.0min
# Episode: 8/1500, Total Reward: -29.87, Avg Reward (last 100): -148.87, Epsilon: 0.986
# Ep: 8/1500 | Reward: -29.9 | Avg: -148.9 | ε: 0.986 | Loss: 0.0000 | Time: 0.0min
# Episode: 9/1500, Total Reward: -162.16, Avg Reward (last 100): -150.35, Epsilon: 0.984
# Ep: 9/1500 | Reward: -162.2 | Avg: -150.4 | ε: 0.984 | Loss: 0.0000 | Time: 0.0min
# Episode: 10/1500, Total Reward: -112.25, Avg Reward (last 100): -146.54, Epsilon: 0.982
# Ep: 10/1500 | Reward: -112.2 | Avg: -146.5 | ε: 0.982 | Loss: 0.0000 | Time: 0.0min
# Memoria actual: 1004, Batch size: 64
# Recompensas batch - min: -4.827273845672607, max: 6.227190017700195, mean: -0.6184674501419067
# Dones en batch: 0.0 de 64
# Targets sample: [ 4.325009  -1.6671836 -4.4692473  0.9352617 -1.8040402]
# Current Q values sample: [-0.8295281   0.6034065  -0.6352755   0.29544768 -0.48142383]
# Normas de gradientes: [np.float32(0.2828415), np.float32(0.1989639), np.float32(0.8621562), np.float32(0.22018711), np.float32(0.7685049), np.float32(0.22268133)]
# Loss actual (step 0): 1.1484311819076538
# Memoria actual: 1008, Batch size: 64
# Recompensas batch - min: -100.0, max: 9.56441879272461, mean: -3.651215076446533
# Dones en batch: 2.0 de 64
# Targets sample: [  -2.3189142 -100.          -2.076227    11.144665    -1.3950281]
# Current Q values sample: [ 0.14462431 -0.5213449   1.1110611   1.0487425  -0.62619054]
# Normas de gradientes: [np.float32(0.18932337), np.float32(0.12769064), np.float32(0.5042261), np.float32(0.1372003), np.float32(0.63192147), np.float32(0.19683774)]
# Memoria actual: 1012, Batch size: 64
# Recompensas batch - min: -100.0, max: 5.756976127624512, mean: -1.9564054012298584
# Dones en batch: 1.0 de 64
# Targets sample: [-0.05079961 -0.53143513  5.354154    1.9830348   1.1091278 ]
# Current Q values sample: [ 0.5084401  -0.07699617 -0.2832566  -0.86433053 -0.8164068 ]
# Normas de gradientes: [np.float32(0.21610671), np.float32(0.15710396), np.float32(0.5862717), np.float32(0.15255153), np.float32(0.67767435), np.float32(0.20867231)]
# Memoria actual: 1016, Batch size: 64
# Recompensas batch - min: -100.0, max: 6.137147903442383, mean: -5.209605693817139
# Dones en batch: 3.0 de 64
# Targets sample: [-3.1840773   0.33984593  2.8543847  -0.0093807  -0.6999872 ]
# Current Q values sample: [-0.71707237  0.26075712 -0.5290989  -0.23584898 -0.64894354]
# Normas de gradientes: [np.float32(0.26511645), np.float32(0.17943461), np.float32(0.77202076), np.float32(0.20104228), np.float32(0.7849476), np.float32(0.23595944)]
# Memoria actual: 1020, Batch size: 64
# Recompensas batch - min: -3.258931875228882, max: 4.447527885437012, mean: -0.776221752166748
# Dones en batch: 0.0 de 64
# Targets sample: [ 2.2139091   0.25385368 -1.4102606   1.0091393  -0.9451894 ]
# Current Q values sample: [-0.9528542   0.61254567  0.07232674 -0.8548278  -0.52108186]
# Normas de gradientes: [np.float32(0.3320807), np.float32(0.2497548), np.float32(0.90214443), np.float32(0.25452587), np.float32(0.9345338), np.float32(0.29648018)]
# Memoria actual: 1024, Batch size: 64
# Recompensas batch - min: -7.117313385009766, max: 4.255559921264648, mean: -0.9557848572731018
# Dones en batch: 0.0 de 64
# Targets sample: [-1.1592047 -0.4431975  4.349071  -0.3624478 -1.315549 ]
# Current Q values sample: [-0.46877483 -0.53468686 -0.96258754  0.17617099 -0.4456276 ]
# Normas de gradientes: [np.float32(0.19669996), np.float32(0.13685994), np.float32(0.5982933), np.float32(0.14741875), np.float32(0.5549754), np.float32(0.15843326)]
# Memoria actual: 1028, Batch size: 64
# Recompensas batch - min: -3.5745718479156494, max: 27.281818389892578, mean: -0.042919740080833435
# Dones en batch: 0.0 de 64
# Targets sample: [ 2.9822912   1.0517588  -0.14416158 -1.4935714  -1.6462321 ]
# Current Q values sample: [-0.32411617 -0.7984061  -0.3705495  -0.8123771  -0.34551433]
# Normas de gradientes: [np.float32(0.24257848), np.float32(0.15483445), np.float32(0.6507867), np.float32(0.15399629), np.float32(0.6221796), np.float32(0.16638318)]
# Episode: 11/1500, Total Reward: -87.21, Avg Reward (last 100): -141.15, Epsilon: 0.980
# Ep: 11/1500 | Reward: -87.2 | Avg: -141.1 | ε: 0.980 | Loss: 0.2662 | Time: 0.0min
# Memoria actual: 1032, Batch size: 64
# Recompensas batch - min: -3.325657367706299, max: 104.51860809326172, mean: 1.0681111812591553
# Dones en batch: 0.0 de 64
# Targets sample: [-1.4549674   0.74130595 -2.831159   -0.979587   -0.94225425]
# Current Q values sample: [-1.0200421   0.13545245 -0.95450276 -0.37925935 -0.48922184]
# Normas de gradientes: [np.float32(0.18808725), np.float32(0.12114501), np.float32(0.4437076), np.float32(0.10362175), np.float32(0.5150225), np.float32(0.14651866)]
# Memoria actual: 1036, Batch size: 64
# Recompensas batch - min: -100.0, max: 104.51860809326172, mean: -0.3828084468841553
# Dones en batch: 1.0 de 64
# Targets sample: [-0.22107217  3.366842   -2.7840457  -1.3791487   3.9783776 ]
# Current Q values sample: [-0.03730839 -0.674974   -0.98553383 -0.51172775 -0.12876347]
# Normas de gradientes: [np.float32(0.21328284), np.float32(0.16047128), np.float32(0.5310975), np.float32(0.15980734), np.float32(0.698581), np.float32(0.23106328)]
# Memoria actual: 1040, Batch size: 64
# Recompensas batch - min: -5.88577938079834, max: 4.255559921264648, mean: -0.8949002027511597
# Dones en batch: 0.0 de 64
# Targets sample: [-3.4162889   0.44443154 -2.301282   -1.6153328  -1.2944368 ]
# Current Q values sample: [-0.6966585   0.15625419 -0.5077145   0.29510948 -1.1240404 ]
# Normas de gradientes: [np.float32(0.20697086), np.float32(0.15008879), np.float32(0.6372356), np.float32(0.17700598), np.float32(0.5537075), np.float32(0.15605934)]
# Memoria actual: 1044, Batch size: 64
# Recompensas batch - min: -100.0, max: 10.073201179504395, mean: -1.998517394065857
# Dones en batch: 1.0 de 64
# Targets sample: [-0.74868035 -5.3047585   0.3433192  -1.944444   -0.45245075]
# Current Q values sample: [-0.46015656 -0.77977294 -0.6233009  -0.56488186 -0.13504598]
# Normas de gradientes: [np.float32(0.21852423), np.float32(0.14873712), np.float32(0.627962), np.float32(0.16352138), np.float32(0.6341909), np.float32(0.159871)]
# Memoria actual: 1048, Batch size: 64
# Recompensas batch - min: -8.548149108886719, max: 3.553093433380127, mean: -0.7688838243484497
# Dones en batch: 0.0 de 64
# Targets sample: [ 0.10290331  0.19159135 -1.9327312  -1.4625163  -1.9488428 ]
# Current Q values sample: [-0.31585082  0.07129741 -1.5364882  -0.5056616  -0.2448227 ]
# Normas de gradientes: [np.float32(0.23152123), np.float32(0.16174099), np.float32(0.60175014), np.float32(0.16565675), np.float32(0.6290191), np.float32(0.18830338)]
# Memoria actual: 1052, Batch size: 64
# Recompensas batch - min: -5.03751277923584, max: 9.617703437805176, mean: -0.8684476017951965
# Dones en batch: 0.0 de 64
# Targets sample: [-0.9850602   0.00433877 -2.8598824  -1.6114289  -3.4828663 ]
# Current Q values sample: [-0.7845304  -0.26400778 -1.2599612  -0.46521083 -0.46549472]
# Normas de gradientes: [np.float32(0.24540353), np.float32(0.16875757), np.float32(0.70209116), np.float32(0.19266538), np.float32(0.7292546), np.float32(0.20146279)]
# Memoria actual: 1056, Batch size: 64
# Recompensas batch - min: -100.0, max: 4.1068434715271, mean: -2.093255043029785
# Dones en batch: 1.0 de 64
# Targets sample: [ 2.7772753  3.413455   0.1907565  1.845289  -1.6470448]
# Current Q values sample: [-0.536757   -0.6542371  -0.9683309  -0.24996348 -0.49230713]
# Normas de gradientes: [np.float32(0.19906734), np.float32(0.13217995), np.float32(0.4649444), np.float32(0.11535436), np.float32(0.52934), np.float32(0.15670124)]
# Memoria actual: 1060, Batch size: 64
# Recompensas batch - min: -3.5745718479156494, max: 9.56441879272461, mean: -0.4151344895362854
# Dones en batch: 0.0 de 64
# Targets sample: [ 1.9153801 -1.8530428 -0.7048084 -1.6953423 -1.7226884]
# Current Q values sample: [-0.68914056 -0.5961494  -1.0552117  -0.69350743 -1.4632052 ]
# Normas de gradientes: [np.float32(0.21580705), np.float32(0.15161866), np.float32(0.58381164), np.float32(0.14924332), np.float32(0.5677592), np.float32(0.16137227)]
# Memoria actual: 1064, Batch size: 64
# Recompensas batch - min: -100.0, max: 3.7910540103912354, mean: -2.634488105773926
# Dones en batch: 1.0 de 64
# Targets sample: [  -0.26931083   -2.4584982    -2.6017406  -100.           -4.36421   ]
# Current Q values sample: [-0.12805355 -0.48371893 -1.0556184  -1.7969749  -0.17647953]
# Normas de gradientes: [np.float32(0.20454039), np.float32(0.13276088), np.float32(0.6015865), np.float32(0.14147441), np.float32(0.63902205), np.float32(0.16420709)]
# Memoria actual: 1068, Batch size: 64
# Recompensas batch - min: -5.691220283508301, max: 5.756976127624512, mean: -0.5594557523727417
# Dones en batch: 0.0 de 64
# Targets sample: [ 0.9975221  -0.27032304 -0.9303301  -1.423172    0.663574  ]
# Current Q values sample: [-0.0757919  -0.44417247 -0.5806466  -0.7154838  -0.23153293]
# Normas de gradientes: [np.float32(0.16980143), np.float32(0.12104095), np.float32(0.5148197), np.float32(0.1309983), np.float32(0.6476333), np.float32(0.18349966)]
# Memoria actual: 1072, Batch size: 64
# Recompensas batch - min: -100.0, max: 9.617703437805176, mean: -1.7937819957733154
# Dones en batch: 1.0 de 64
# Targets sample: [-1.8734246 -6.3428016 -2.5141428 -2.2295206  1.8366543]
# Current Q values sample: [-0.6492064  -0.30254176 -0.40112975 -0.6273631   0.11543118]
# Normas de gradientes: [np.float32(0.22994944), np.float32(0.15456289), np.float32(0.5124524), np.float32(0.13444754), np.float32(0.5050602), np.float32(0.15250902)]
# Memoria actual: 1076, Batch size: 64
# Recompensas batch - min: -3.927586078643799, max: 3.8191604614257812, mean: -0.6135159730911255
# Dones en batch: 0.0 de 64
# Targets sample: [-0.9406185   0.10053706 -0.8131975   0.01684567 -2.3632236 ]
# Current Q values sample: [-0.75997925 -0.29241484 -1.0791075  -0.3741873  -0.8239559 ]
# Normas de gradientes: [np.float32(0.17949109), np.float32(0.11946557), np.float32(0.41514525), np.float32(0.10504745), np.float32(0.46297115), np.float32(0.12207838)]
# Memoria actual: 1080, Batch size: 64
# Recompensas batch - min: -100.0, max: 8.806502342224121, mean: -3.9285354614257812
# Dones en batch: 2.0 de 64
# Targets sample: [-3.4720993   0.95688444 -1.9145863  -2.9334457  -1.7540836 ]
# Current Q values sample: [-1.4516475  -1.4059651  -0.81334585 -1.1572396  -1.7583284 ]
# Normas de gradientes: [np.float32(0.25238895), np.float32(0.17452878), np.float32(0.7044551), np.float32(0.17521815), np.float32(0.75681), np.float32(0.18982136)]
# Memoria actual: 1084, Batch size: 64
# Recompensas batch - min: -7.117313385009766, max: 4.169414043426514, mean: -0.733593225479126
# Dones en batch: 0.0 de 64
# Targets sample: [-1.8311265e+00 -2.7087927e-03 -2.9717729e+00  2.1988547e+00
#  -1.6278336e+00]
# Current Q values sample: [-0.606734   -0.49287838 -0.5914254  -0.46906862 -1.0889612 ]
# Normas de gradientes: [np.float32(0.2418789), np.float32(0.17690866), np.float32(0.6964488), np.float32(0.1875667), np.float32(0.76368004), np.float32(0.22634593)]
# Memoria actual: 1088, Batch size: 64
# Recompensas batch - min: -100.0, max: 4.7015910148620605, mean: -3.7903969287872314
# Dones en batch: 2.0 de 64
# Targets sample: [-3.190873   -1.4166403  -0.63064444 -2.3349154  -0.6998763 ]
# Current Q values sample: [-1.6771591  -0.93395865 -0.5257087  -0.8199268  -0.8883948 ]
# Normas de gradientes: [np.float32(0.21823956), np.float32(0.14487813), np.float32(0.60610723), np.float32(0.16524528), np.float32(0.74272406), np.float32(0.1950461)]
# Memoria actual: 1092, Batch size: 64
# Recompensas batch - min: -100.0, max: 9.617703437805176, mean: -1.8062832355499268
# Dones en batch: 1.0 de 64
# Targets sample: [-1.6984246  -0.42379215 -2.4488802  -1.8664951  -1.8552592 ]
# Current Q values sample: [-1.5403246  -1.047365   -1.087338   -0.93195635 -0.85490584]
# Normas de gradientes: [np.float32(0.24063852), np.float32(0.17138983), np.float32(0.6725678), np.float32(0.17587014), np.float32(0.6955222), np.float32(0.19505666)]
# Memoria actual: 1096, Batch size: 64
# Recompensas batch - min: -100.0, max: 6.591519832611084, mean: -1.8653525114059448
# Dones en batch: 1.0 de 64
# Targets sample: [-2.731064    0.7682637  -1.6693382  -1.215976   -0.58314353]
# Current Q values sample: [-1.8925256  -0.33739626 -1.6571535  -0.39268166  0.16727893]
# Normas de gradientes: [np.float32(0.2510748), np.float32(0.18782096), np.float32(0.6270232), np.float32(0.17927137), np.float32(0.69584966), np.float32(0.19213286)]
# Memoria actual: 1100, Batch size: 64
# Recompensas batch - min: -3.202561378479004, max: 104.51860809326172, mean: 1.1613333225250244
# Dones en batch: 0.0 de 64
# Targets sample: [-1.0562042 -3.1943164 -1.904877  -3.6324186 -0.093665 ]
# Current Q values sample: [-1.1609358 -0.5356144 -0.8541491 -1.8654178 -0.9682806]
# Normas de gradientes: [np.float32(0.2147293), np.float32(0.14935775), np.float32(0.5325717), np.float32(0.13455328), np.float32(0.57871544), np.float32(0.14231272)]
# Memoria actual: 1104, Batch size: 64
# Recompensas batch - min: -100.0, max: 27.281818389892578, mean: -1.6478345394134521
# Dones en batch: 1.0 de 64
# Targets sample: [  -1.215976    -3.0125616   -1.2720056 -100.          -2.5843406]
# Current Q values sample: [-0.40256697 -1.8545527  -1.4270198  -1.9081954  -0.92039907]
# Normas de gradientes: [np.float32(0.2596194), np.float32(0.19469252), np.float32(0.66400653), np.float32(0.18585607), np.float32(0.83522886), np.float32(0.24259707)]
# Memoria actual: 1108, Batch size: 64
# Recompensas batch - min: -100.0, max: 7.60544490814209, mean: -3.612316608428955
# Dones en batch: 2.0 de 64
# Targets sample: [-5.651011  -3.50163   -0.7852987 -2.9969804  5.209932 ]
# Current Q values sample: [-0.7534688  -1.8833392  -0.85166115 -2.401253   -0.16085398]
# Normas de gradientes: [np.float32(0.2270738), np.float32(0.15132338), np.float32(0.5373437), np.float32(0.13120897), np.float32(0.52269995), np.float32(0.110619016)]
# Memoria actual: 1112, Batch size: 64
# Recompensas batch - min: -3.537851095199585, max: 18.049142837524414, mean: 0.06381151080131531
# Dones en batch: 0.0 de 64
# Targets sample: [-0.21685722  2.4504964  -3.0967927  -0.57666945 -2.080967  ]
# Current Q values sample: [-0.15331614 -0.07072769 -1.57106    -0.75494397 -1.1282653 ]
# Normas de gradientes: [np.float32(0.19587895), np.float32(0.13610265), np.float32(0.4279162), np.float32(0.10973445), np.float32(0.607257), np.float32(0.15930407)]
# Memoria actual: 1116, Batch size: 64
# Recompensas batch - min: -100.0, max: 3.8932230472564697, mean: -1.8999360799789429
# Dones en batch: 1.0 de 64
# Targets sample: [ 2.735954   -2.3569756  -0.9565388  -2.5543668  -0.15088636]
# Current Q values sample: [ 0.08004139 -1.9398901  -1.3246629  -1.6178064  -1.2175407 ]
# Normas de gradientes: [np.float32(0.20005165), np.float32(0.13177979), np.float32(0.42365888), np.float32(0.11026259), np.float32(0.4234546), np.float32(0.10193669)]
# Memoria actual: 1120, Batch size: 64
# Recompensas batch - min: -5.645922660827637, max: 5.744686603546143, mean: -0.39414486289024353
# Dones en batch: 0.0 de 64
# Targets sample: [ 3.8786297 -2.90268    0.8854478 -1.1782581 -1.110809 ]
# Current Q values sample: [ 0.27298012 -1.2604215  -1.4803882  -0.74665797 -1.4562924 ]
# Normas de gradientes: [np.float32(0.21176428), np.float32(0.12941852), np.float32(0.4383935), np.float32(0.10830798), np.float32(0.5128298), np.float32(0.13038298)]
# Memoria actual: 1124, Batch size: 64
# Recompensas batch - min: -3.793942451477051, max: 4.169414043426514, mean: -0.6237460970878601
# Dones en batch: 0.0 de 64
# Targets sample: [-0.8216265  -0.42132318 -2.1482646  -2.7395787  -1.5801497 ]
# Current Q values sample: [-0.8330528 -0.5651539 -2.2747514 -1.2660825 -2.1785002]
# Normas de gradientes: [np.float32(0.14139459), np.float32(0.09648914), np.float32(0.39687994), np.float32(0.11002994), np.float32(0.48443893), np.float32(0.12611891)]
# Memoria actual: 1128, Batch size: 64
# Recompensas batch - min: -5.88577938079834, max: 7.115330219268799, mean: -0.4463309347629547
# Dones en batch: 0.0 de 64
# Targets sample: [-2.2931945  -0.75247896 -1.9704151   3.1701062  -1.4311564 ]
# Current Q values sample: [-2.1801884  -1.1337655  -1.125949   -0.69723725 -2.1996026 ]
# Normas de gradientes: [np.float32(0.17665721), np.float32(0.11605717), np.float32(0.37932888), np.float32(0.09864229), np.float32(0.49703327), np.float32(0.11754836)]
# Episode: 12/1500, Total Reward: -149.88, Avg Reward (last 100): -141.87, Epsilon: 0.978
# Memoria actual: 1132, Batch size: 64
# Recompensas batch - min: -3.5745718479156494, max: 3.0851590633392334, mean: -0.8718457818031311
# Dones en batch: 0.0 de 64
# Targets sample: [-1.6452433 -2.1837635 -3.2034807 -2.9334457 -0.957734 ]
# Current Q values sample: [ 0.19727008 -1.6221826  -1.2388316  -1.9145727  -1.0543785 ]
# Normas de gradientes: [np.float32(0.1916087), np.float32(0.122324176), np.float32(0.4939084), np.float32(0.12400539), np.float32(0.51576865), np.float32(0.11876288)]
# Memoria actual: 1136, Batch size: 64
# Recompensas batch - min: -100.0, max: 5.534492015838623, mean: -3.7929084300994873
# Dones en batch: 2.0 de 64
# Targets sample: [-1.4221938  -0.42379215 -3.1452394  -0.5757308   0.14163285]
# Current Q values sample: [-1.5056927  -1.121665   -1.9966661  -0.85133207 -0.12151282]
# Normas de gradientes: [np.float32(0.175035), np.float32(0.08972093), np.float32(0.38319135), np.float32(0.083642304), np.float32(0.4488406), np.float32(0.07957661)]
# Memoria actual: 1140, Batch size: 64
# Recompensas batch - min: -100.0, max: 27.281818389892578, mean: -1.7236456871032715
# Dones en batch: 1.0 de 64
# Targets sample: [-0.6589348 -3.3765206 -1.8507597 -0.8131975 -2.937402 ]
# Current Q values sample: [ 0.21577074 -1.5280236  -1.7247949  -2.209922   -2.5337572 ]
# Normas de gradientes: [np.float32(0.19083941), np.float32(0.11445397), np.float32(0.46235198), np.float32(0.1019965), np.float32(0.5093023), np.float32(0.09792538)]
# Memoria actual: 1144, Batch size: 64
# Recompensas batch - min: -100.0, max: 4.888950824737549, mean: -5.538704872131348
# Dones en batch: 3.0 de 64
# Targets sample: [-1.8096197 -2.9236774 -2.3174915 -2.2747414 -1.206522 ]
# Current Q values sample: [-2.17884    -1.2410792   0.48849893 -2.0121434  -1.4178123 ]
# Normas de gradientes: [np.float32(0.181438), np.float32(0.114267305), np.float32(0.4466316), np.float32(0.117921114), np.float32(0.60844266), np.float32(0.12996991)]
# Memoria actual: 1148, Batch size: 64
# Recompensas batch - min: -6.386390209197998, max: 7.115330219268799, mean: -1.0682207345962524
# Dones en batch: 0.0 de 64
# Targets sample: [-2.536428   -0.8370466  -2.4918702  -0.5959655  -0.78105307]
# Current Q values sample: [-2.4545689  -1.3183624  -2.2943587  -0.81780267 -1.865212  ]
# Normas de gradientes: [np.float32(0.14669149), np.float32(0.09181954), np.float32(0.37033466), np.float32(0.085641846), np.float32(0.38801116), np.float32(0.0711775)]
# Memoria actual: 1152, Batch size: 64
# Recompensas batch - min: -100.0, max: 10.073201179504395, mean: -2.1035284996032715
# Dones en batch: 1.0 de 64
# Targets sample: [-2.2748365  0.7413292 -1.904877  -4.2584724  1.0146146]
# Current Q values sample: [-2.103834   -1.3448204  -1.4402369  -2.867295    0.14086357]
# Normas de gradientes: [np.float32(0.17335299), np.float32(0.09026333), np.float32(0.38854623), np.float32(0.07339249), np.float32(0.39956647), np.float32(0.07842715)]
# Memoria actual: 1156, Batch size: 64
# Recompensas batch - min: -6.543637752532959, max: 104.51860809326172, mean: 1.234321117401123
# Dones en batch: 0.0 de 64
# Targets sample: [-2.018091   -0.84488046 -2.4918702   2.2502756  -2.90268   ]
# Current Q values sample: [-2.2694793 -1.1026418 -2.3580978  0.2173999 -1.6213014]
# Normas de gradientes: [np.float32(0.19482394), np.float32(0.12229923), np.float32(0.48589566), np.float32(0.11881135), np.float32(0.6160147), np.float32(0.12930502)]
# Memoria actual: 1160, Batch size: 64
# Recompensas batch - min: -100.0, max: 3.9016566276550293, mean: -3.7356882095336914
# Dones en batch: 2.0 de 64
# Targets sample: [  -2.3353224   -3.256272    -1.6018841    2.2998333 -100.       ]
# Current Q values sample: [-1.7374448 -1.6052834 -3.1243265 -0.4471781 -1.4870774]
# Normas de gradientes: [np.float32(0.20297006), np.float32(0.11216852), np.float32(0.37205958), np.float32(0.076361634), np.float32(0.41366026), np.float32(0.08929561)]
# Memoria actual: 1164, Batch size: 64
# Recompensas batch - min: -100.0, max: 10.073201179504395, mean: -2.261512517929077
# Dones en batch: 1.0 de 64
# Targets sample: [-1.9226351 -0.3308614 -2.928703  -3.3324108 -2.1670458]
# Current Q values sample: [-2.0936677 -1.2770511 -3.285063  -2.6957421 -1.666664 ]
# Normas de gradientes: [np.float32(0.20309019), np.float32(0.121975385), np.float32(0.53631335), np.float32(0.11751419), np.float32(0.5887421), np.float32(0.11789961)]
# Memoria actual: 1168, Batch size: 64
# Recompensas batch - min: -5.645922660827637, max: 4.1068434715271, mean: -0.8519231677055359
# Dones en batch: 0.0 de 64
# Targets sample: [-2.9842377  -0.7117665   0.46812952 -2.7185898   3.7183986 ]
# Current Q values sample: [-3.0997267  -2.0059214  -0.6155634  -2.416714    0.11664309]
# Normas de gradientes: [np.float32(0.111781254), np.float32(0.0640145), np.float32(0.25994006), np.float32(0.043463193), np.float32(0.25860694), np.float32(0.03582675)]
# Memoria actual: 1172, Batch size: 64
# Recompensas batch - min: -2.6895668506622314, max: 5.679253578186035, mean: -0.21666133403778076
# Dones en batch: 0.0 de 64
# Targets sample: [-2.7395787 -2.2924862 -1.503803   2.2998333  1.3275406]
# Current Q values sample: [-1.9364513  -2.460151   -1.727618   -0.43825135 -0.6103001 ]
# Normas de gradientes: [np.float32(0.18589169), np.float32(0.11226297), np.float32(0.38617182), np.float32(0.06956002), np.float32(0.43890512), np.float32(0.07560098)]
# Memoria actual: 1176, Batch size: 64
# Recompensas batch - min: -5.645922660827637, max: 4.796308517456055, mean: -0.4628594219684601
# Dones en batch: 0.0 de 64
# Targets sample: [-0.7433347 -2.907752  -2.346411  -1.1977835 -0.6870725]
# Current Q values sample: [-2.252357  -3.7907546 -2.5429115 -1.2280567 -1.0042924]
# Normas de gradientes: [np.float32(0.26762062), np.float32(0.1767522), np.float32(0.67123723), np.float32(0.16722971), np.float32(0.7019613), np.float32(0.15582693)]
# Memoria actual: 1180, Batch size: 64
# Recompensas batch - min: -6.047372817993164, max: 4.796308517456055, mean: -0.851090133190155
# Dones en batch: 0.0 de 64
# Targets sample: [-1.8265512  -2.8020732  -5.9104185  -0.18404521 -2.5497637 ]
# Current Q values sample: [-1.3248487  -2.2516754   0.15277624 -0.62384623 -1.9703091 ]
# Normas de gradientes: [np.float32(0.20151946), np.float32(0.11052621), np.float32(0.43024662), np.float32(0.09015279), np.float32(0.40699172), np.float32(0.0819299)]
# Memoria actual: 1184, Batch size: 64
# Recompensas batch - min: -100.0, max: 3.1366147994995117, mean: -1.976371169090271
# Dones en batch: 1.0 de 64
# Targets sample: [-0.6134901 -2.5354369 -1.0809084  1.548043   2.6929417]
# Current Q values sample: [-1.0087144  -1.5046753  -1.678921    0.3400383   0.58044255]
# Normas de gradientes: [np.float32(0.24306478), np.float32(0.1622946), np.float32(0.5981727), np.float32(0.14067207), np.float32(0.62245643), np.float32(0.12023455)]
# Memoria actual: 1188, Batch size: 64
# Recompensas batch - min: -100.0, max: 7.115330219268799, mean: -1.9595497846603394
# Dones en batch: 1.0 de 64
# Targets sample: [-1.4271975  -0.78105307  1.7514757  -2.2295206  -2.2931945 ]
# Current Q values sample: [-1.6036845  -2.0888765   0.02615237 -0.70066404 -2.5394168 ]
# Normas de gradientes: [np.float32(0.20230325), np.float32(0.12891693), np.float32(0.4847713), np.float32(0.10670401), np.float32(0.5808968), np.float32(0.11423943)]
# Memoria actual: 1192, Batch size: 64
# Recompensas batch - min: -100.0, max: 18.049142837524414, mean: -1.6957350969314575
# Dones en batch: 1.0 de 64
# Targets sample: [-1.8927221 -2.3995647 -2.995627  -2.7185898 -2.599065 ]
# Current Q values sample: [-2.4490461 -2.174477  -2.785796  -2.4674582 -1.9882623]
# Normas de gradientes: [np.float32(0.23012176), np.float32(0.14868475), np.float32(0.52790385), np.float32(0.13106774), np.float32(0.5821537), np.float32(0.13180245)]
# Memoria actual: 1196, Batch size: 64
# Recompensas batch - min: -7.117313385009766, max: 5.534492015838623, mean: -0.2002793848514557
# Dones en batch: 0.0 de 64
# Targets sample: [-2.7124658  -0.75247896  1.1174481  -3.4330297  -3.1419058 ]
# Current Q values sample: [-2.972591   -0.9754655  -0.84122306 -1.7998738  -2.174794  ]
# Normas de gradientes: [np.float32(0.28969198), np.float32(0.21438725), np.float32(0.78901154), np.float32(0.20713589), np.float32(0.7432491), np.float32(0.17336312)]
# Memoria actual: 1200, Batch size: 64
# Recompensas batch - min: -100.0, max: 104.51860809326172, mean: -0.7432800531387329
# Dones en batch: 1.0 de 64
# Targets sample: [-2.2728586  -1.5174885   0.27026793 -1.800212   -2.3608017 ]
# Current Q values sample: [-1.8580296  -2.0287848   0.49486032 -2.0761027  -2.1270452 ]
# Normas de gradientes: [np.float32(0.20988984), np.float32(0.12959515), np.float32(0.52070725), np.float32(0.10524899), np.float32(0.57695585), np.float32(0.0988419)]
# Memoria actual: 1204, Batch size: 64
# Recompensas batch - min: -7.414126873016357, max: 3.612050771713257, mean: -0.8002212643623352
# Dones en batch: 0.0 de 64
# Targets sample: [-3.4330297   1.9799702  -1.5832071   1.1372952  -0.78105307]
# Current Q values sample: [-1.7430106  -0.5467832  -1.4344659  -0.17759968 -1.9725549 ]
# Normas de gradientes: [np.float32(0.22594398), np.float32(0.13064334), np.float32(0.5273948), np.float32(0.09359137), np.float32(0.74290013), np.float32(0.12782568)]
# Memoria actual: 1208, Batch size: 64
# Recompensas batch - min: -100.0, max: 4.137895107269287, mean: -2.0530753135681152
# Dones en batch: 1.0 de 64
# Targets sample: [-2.4720373  3.5162485 -3.0541801 -1.5045884 -2.811905 ]
# Current Q values sample: [-2.035947   0.9410093 -3.1182454 -1.9113216 -1.5989023]
# Normas de gradientes: [np.float32(0.16376284), np.float32(0.10172257), np.float32(0.35507986), np.float32(0.07968607), np.float32(0.35973674), np.float32(0.082400635)]
# Memoria actual: 1212, Batch size: 64
# Recompensas batch - min: -6.1442975997924805, max: 5.746397972106934, mean: -0.9105709791183472
# Dones en batch: 0.0 de 64
# Targets sample: [-1.9553926  2.4101613 -0.6647072 -2.8940773 -2.494014 ]
# Current Q values sample: [-2.117257   -0.12864406 -1.1522725  -2.9654572  -2.956841  ]
# Normas de gradientes: [np.float32(0.15801717), np.float32(0.093859844), np.float32(0.35642067), np.float32(0.06874751), np.float32(0.40085593), np.float32(0.06628418)]
# Episode: 13/1500, Total Reward: 13.26, Avg Reward (last 100): -129.94, Epsilon: 0.977
# Memoria actual: 1216, Batch size: 64
# Recompensas batch - min: -100.0, max: 5.756976127624512, mean: -2.2970080375671387
# Dones en batch: 1.0 de 64
# Targets sample: [-1.6492089 -1.3073016 -2.9044766 -0.6870725  5.010229 ]
# Current Q values sample: [-1.3582176  -2.3403978  -1.7215512  -0.94816065 -0.04701928]
# Normas de gradientes: [np.float32(0.19228922), np.float32(0.1428619), np.float32(0.3502137), np.float32(0.0997106), np.float32(0.37304792), np.float32(0.099397995)]
# Memoria actual: 1220, Batch size: 64
# Recompensas batch - min: -3.532914400100708, max: 13.990330696105957, mean: -0.37681257724761963
# Dones en batch: 0.0 de 64
# Targets sample: [-3.7079096 -1.2906795 -1.5045884 -0.7696569  6.830639 ]
# Current Q values sample: [-1.182167  -2.1129758 -1.8090999 -1.9507372 -1.3960948]
# Normas de gradientes: [np.float32(0.16492039), np.float32(0.10147672), np.float32(0.3314534), np.float32(0.06954089), np.float32(0.34005022), np.float32(0.05845516)]
# Memoria actual: 1224, Batch size: 64
# Recompensas batch - min: -3.5745718479156494, max: 104.51860809326172, mean: 1.2983311414718628
# Dones en batch: 0.0 de 64
# Targets sample: [-0.46165583 -1.9991229  -2.3172913  -3.001768    1.0450528 ]
# Current Q values sample: [-3.2820010e-01 -1.6211871e+00 -1.6994147e+00 -2.3595886e+00
#  -2.2535883e-03]
# Normas de gradientes: [np.float32(0.17622419), np.float32(0.11336498), np.float32(0.4461221), np.float32(0.10366607), np.float32(0.3915184), np.float32(0.079551846)]
# Memoria actual: 1228, Batch size: 64
# Recompensas batch - min: -2.851332426071167, max: 21.265439987182617, mean: -0.14578771591186523
# Dones en batch: 0.0 de 64
# Targets sample: [-1.8227136 -2.2810771 -1.477883  -2.8721943 -0.5959655]
# Current Q values sample: [-1.0943415 -2.0319068 -1.1649793 -2.4261744 -0.8803711]
# Normas de gradientes: [np.float32(0.19590491), np.float32(0.12423241), np.float32(0.46835572), np.float32(0.115989804), np.float32(0.46897823), np.float32(0.09558988)]
# Memoria actual: 1232, Batch size: 64
# Recompensas batch - min: -3.6297435760498047, max: 4.934088230133057, mean: -0.5965526103973389
# Dones en batch: 0.0 de 64
# Targets sample: [ 0.6025717  -1.9726555  -1.4576906  -1.0588349  -0.43858615]
# Current Q values sample: [ 1.0144986  -1.4572401  -1.2013702  -0.65477943 -1.4316068 ]
# Normas de gradientes: [np.float32(0.13419108), np.float32(0.086147785), np.float32(0.3299932), np.float32(0.06798611), np.float32(0.35736328), np.float32(0.06779608)]
# Memoria actual: 1236, Batch size: 64
# Recompensas batch - min: -100.0, max: 4.255405426025391, mean: -2.6000375747680664
# Dones en batch: 1.0 de 64
# Targets sample: [-2.5467682  -1.1025863   0.12827721 -2.1405141  -2.2128668 ]
# Current Q values sample: [-2.63231    -0.9739387  -0.72750324 -1.9469355  -1.8263543 ]
# Normas de gradientes: [np.float32(0.25878206), np.float32(0.19649658), np.float32(0.6640148), np.float32(0.17591794), np.float32(0.6906259), np.float32(0.15515707)]
# Memoria actual: 1240, Batch size: 64
# Recompensas batch - min: -6.1442975997924805, max: 4.96096658706665, mean: -0.7147676348686218
# Dones en batch: 0.0 de 64
# Targets sample: [-2.4839418   2.548522   -0.16661173 -3.453901   -3.0996795 ]
# Current Q values sample: [-1.9312602  -0.06474021 -0.58629125 -1.3517011  -1.8819925 ]
# Normas de gradientes: [np.float32(0.22636817), np.float32(0.14548878), np.float32(0.52568567), np.float32(0.118723765), np.float32(0.48359424), np.float32(0.08951058)]
# Memoria actual: 1244, Batch size: 64
# Recompensas batch - min: -100.0, max: 5.756976127624512, mean: -2.1447877883911133
# Dones en batch: 1.0 de 64
# Targets sample: [-0.2711478  -2.649851   -0.48703235 -3.5230143  -7.415475  ]
# Current Q values sample: [-0.56615144 -2.3090904  -1.1956367  -2.2219367   0.0354276 ]
# Normas de gradientes: [np.float32(0.18432261), np.float32(0.09949696), np.float32(0.41275334), np.float32(0.07989514), np.float32(0.36283424), np.float32(0.06233743)]
# Memoria actual: 1248, Batch size: 64
# Recompensas batch - min: -100.0, max: 7.346674919128418, mean: -2.180065155029297
# Dones en batch: 1.0 de 64
# Targets sample: [-1.8265512  0.819579  -1.5801497 -2.2879896 -1.8198613]
# Current Q values sample: [-1.0535288  -0.38231853 -2.2231364  -0.8662441  -2.733083  ]
# Normas de gradientes: [np.float32(0.14123122), np.float32(0.06798513), np.float32(0.3530953), np.float32(0.053902384), np.float32(0.36953214), np.float32(0.04105238)]
# Memoria actual: 1252, Batch size: 64
# Recompensas batch - min: -3.6297435760498047, max: 7.115330219268799, mean: -0.6703112125396729
# Dones en batch: 0.0 de 64
# Targets sample: [-0.83871    -1.7929798   0.36696503 -1.9419702  -3.453901  ]
# Current Q values sample: [-0.06526341 -1.7205184   0.18413816 -1.3125504  -1.4157568 ]
# Normas de gradientes: [np.float32(0.149732), np.float32(0.086957745), np.float32(0.3032429), np.float32(0.057199646), np.float32(0.23538452), np.float32(0.03296399)]
# Memoria actual: 1256, Batch size: 64
# Recompensas batch - min: -6.386390209197998, max: 6.591519832611084, mean: -0.7863227128982544
# Dones en batch: 0.0 de 64
# Targets sample: [-2.8932974  -3.049395   -5.2907486  -0.45495278 -0.84828657]
# Current Q values sample: [-1.9204501  -1.8044803  -0.71941733 -0.60807645 -1.9902711 ]
# Normas de gradientes: [np.float32(0.17428534), np.float32(0.0779538), np.float32(0.38574898), np.float32(0.062349312), np.float32(0.4169926), np.float32(0.047020912)]
# Memoria actual: 1260, Batch size: 64
# Recompensas batch - min: -100.0, max: 4.140051364898682, mean: -2.163769006729126
# Dones en batch: 1.0 de 64
# Targets sample: [-3.0967927  0.8148998 -1.5610354 -1.0350894  3.9552097]
# Current Q values sample: [-1.8301274  -0.3173386  -2.6133363  -0.60003316 -2.1970198 ]
# Normas de gradientes: [np.float32(0.15988071), np.float32(0.08082397), np.float32(0.32601398), np.float32(0.050486576), np.float32(0.33510137), np.float32(0.018813504)]
# Memoria actual: 1264, Batch size: 64
# Recompensas batch - min: -100.0, max: 5.9800825119018555, mean: -1.9747081995010376
# Dones en batch: 1.0 de 64
# Targets sample: [  -0.5107349    1.7311844   -2.572215    -1.4740798 -100.       ]
# Current Q values sample: [-0.81915987 -0.747439   -2.142485   -1.2351986  -2.4578273 ]
# Normas de gradientes: [np.float32(0.16191983), np.float32(0.08523096), np.float32(0.38454217), np.float32(0.06583834), np.float32(0.33597594), np.float32(0.058202047)]
# Memoria actual: 1268, Batch size: 64
# Recompensas batch - min: -100.0, max: 4.888950824737549, mean: -2.429105520248413
# Dones en batch: 1.0 de 64
# Targets sample: [-2.626297  -2.8689435 -3.1037004  1.2696329 -2.8733582]
# Current Q values sample: [-1.9489846 -2.222452  -3.4134948 -0.7327681 -2.7211623]
# Normas de gradientes: [np.float32(0.21732901), np.float32(0.15723003), np.float32(0.49200028), np.float32(0.12787412), np.float32(0.51019806), np.float32(0.10842168)]
# Memoria actual: 1272, Batch size: 64
# Recompensas batch - min: -100.0, max: 18.049142837524414, mean: -3.777191638946533
# Dones en batch: 2.0 de 64
# Targets sample: [-5.2907486  -1.3655827  -2.1719553  -0.42435908  3.5943475 ]
# Current Q values sample: [-0.8614435  -1.2015778  -1.8013346  -1.1130571  -0.34343144]
# Normas de gradientes: [np.float32(0.1907037), np.float32(0.13611822), np.float32(0.4213014), np.float32(0.103035115), np.float32(0.39595675), np.float32(0.07697913)]
# Memoria actual: 1276, Batch size: 64
# Recompensas batch - min: -4.670988082885742, max: 13.990330696105957, mean: -0.5043900012969971
# Dones en batch: 0.0 de 64
# Targets sample: [-0.42132318 -1.8013246  -2.5497637  -0.10802561  0.22023836]
# Current Q values sample: [-0.6369329  -2.1427712  -2.0575454   0.25771293  0.16876979]
# Normas de gradientes: [np.float32(0.15708767), np.float32(0.098654166), np.float32(0.381109), np.float32(0.0704062), np.float32(0.33138594), np.float32(0.05331199)]
# Memoria actual: 1280, Batch size: 64
# Recompensas batch - min: -100.0, max: 3.4749152660369873, mean: -2.2182910442352295
# Dones en batch: 1.0 de 64
# Targets sample: [-1.5809717 -1.800212  -0.3293474  3.1256022 -1.5126979]
# Current Q values sample: [-1.8590884 -1.8155861 -0.9531502  1.0816052 -1.73519  ]
# Normas de gradientes: [np.float32(0.15640669), np.float32(0.09668334), np.float32(0.3109766), np.float32(0.076439016), np.float32(0.3627804), np.float32(0.07551457)]
# Memoria actual: 1284, Batch size: 64
# Recompensas batch - min: -5.88577938079834, max: 21.265439987182617, mean: -0.3243853747844696
# Dones en batch: 0.0 de 64
# Targets sample: [-0.9565234  -1.4211617  -0.98575705 -1.0556636  -1.7727935 ]
# Current Q values sample: [-1.8356657  -0.58266956 -0.9068458  -1.6479838  -2.1356537 ]
# Normas de gradientes: [np.float32(0.14765549), np.float32(0.08543004), np.float32(0.37632972), np.float32(0.094665796), np.float32(0.4665558), np.float32(0.0987896)]
# Memoria actual: 1288, Batch size: 64
# Recompensas batch - min: -3.5557892322540283, max: 5.755558013916016, mean: -0.3801308870315552
# Dones en batch: 0.0 de 64
# Targets sample: [ 4.5452027  -0.71992123 -0.63064444  1.696933   -2.1719553 ]
# Current Q values sample: [ 0.12219814 -1.0610889  -0.26679713  1.3907162  -1.7629274 ]
# Normas de gradientes: [np.float32(0.17851485), np.float32(0.113025606), np.float32(0.4193517), np.float32(0.10188875), np.float32(0.5689985), np.float32(0.1270027)]
# Memoria actual: 1292, Batch size: 64
# Recompensas batch - min: -3.537851095199585, max: 6.137147903442383, mean: -0.13580793142318726
# Dones en batch: 0.0 de 64
# Targets sample: [-2.1214628   2.2502756  -2.1484296  -0.68684757  4.996885  ]
# Current Q values sample: [-1.6114893   0.46992508 -1.6523864  -0.85958195  0.7810214 ]
# Normas de gradientes: [np.float32(0.22739398), np.float32(0.15746224), np.float32(0.58367), np.float32(0.14341834), np.float32(0.61413616), np.float32(0.13123266)]
# Memoria actual: 1296, Batch size: 64
# Recompensas batch - min: -100.0, max: 3.8072192668914795, mean: -2.4398512840270996
# Dones en batch: 1.0 de 64
# Targets sample: [-2.112143  -1.5174885 -3.3179998 -2.6514611  1.594611 ]
# Current Q values sample: [-1.1900063  -1.6066833  -2.755405   -2.3890276   0.15816912]
# Normas de gradientes: [np.float32(0.17361966), np.float32(0.123609744), np.float32(0.41509432), np.float32(0.106391184), np.float32(0.36537746), np.float32(0.08198832)]
# Episode: 14/1500, Total Reward: -92.05, Avg Reward (last 100): -127.24, Epsilon: 0.975
# Memoria actual: 1300, Batch size: 64
# Recompensas batch - min: -4.827273845672607, max: 7.115330219268799, mean: -0.5908342003822327
# Dones en batch: 0.0 de 64
# Targets sample: [-2.582954   -2.1189387  -1.7726598  -0.94759524  0.78332365]
# Current Q values sample: [-2.3064578  -1.7084569  -1.8597708  -0.92454106 -0.68722993]
# Normas de gradientes: [np.float32(0.1992566), np.float32(0.14006448), np.float32(0.42966047), np.float32(0.11184503), np.float32(0.48083583), np.float32(0.11024262)]
# Memoria actual: 1304, Batch size: 64
# Recompensas batch - min: -100.0, max: 104.51860809326172, mean: -0.35901880264282227
# Dones en batch: 1.0 de 64
# Targets sample: [-0.325007   -1.841921   -0.93586445 21.326027   -2.3415775 ]
# Current Q values sample: [-0.7114263  -2.3155744  -0.34413472 -3.466632   -1.6948528 ]
# Normas de gradientes: [np.float32(0.21585271), np.float32(0.1335778), np.float32(0.45053756), np.float32(0.0996626), np.float32(0.55816233), np.float32(0.115493946)]
# Memoria actual: 1308, Batch size: 64
# Recompensas batch - min: -100.0, max: 5.746397972106934, mean: -5.367455005645752
# Dones en batch: 3.0 de 64
# Targets sample: [-100.         -100.           -3.7835712     0.31910232   -1.8626118 ]
# Current Q values sample: [ 1.1194266  -0.41574246 -0.66381574 -0.2499407  -0.9281252 ]
# Normas de gradientes: [np.float32(0.1476491), np.float32(0.09350812), np.float32(0.34536356), np.float32(0.077595554), np.float32(0.40440047), np.float32(0.08334398)]
# Memoria actual: 1312, Batch size: 64
# Recompensas batch - min: -100.0, max: 15.31848430633545, mean: -1.9044649600982666
# Dones en batch: 1.0 de 64
# Targets sample: [-1.5006194  -0.30875233 -1.6181159  -0.08171564  0.31910232]
# Current Q values sample: [-1.4700336  -0.4236232  -3.1053658  -0.7582305  -0.23460105]
# Normas de gradientes: [np.float32(0.17049734), np.float32(0.10962989), np.float32(0.3561494), np.float32(0.07235078), np.float32(0.42508453), np.float32(0.06336233)]
# Memoria actual: 1316, Batch size: 64
# Recompensas batch - min: -3.793942451477051, max: 7.115330219268799, mean: -0.36433348059654236
# Dones en batch: 0.0 de 64
# Targets sample: [ 0.50310063  3.5560112  -1.6507409  -1.1334047  -1.4736599 ]
# Current Q values sample: [-0.6258923   0.07135135 -2.2686281  -1.76396    -2.1650846 ]
# Normas de gradientes: [np.float32(0.21595915), np.float32(0.14626227), np.float32(0.49593395), np.float32(0.12428648), np.float32(0.5580373), np.float32(0.112156324)]
# Memoria actual: 1320, Batch size: 64
# Recompensas batch - min: -5.691220283508301, max: 3.8932230472564697, mean: -0.6135189533233643
# Dones en batch: 0.0 de 64
# Targets sample: [-2.080967   -0.13367502 -5.944067   -1.5301965  -0.877217  ]
# Current Q values sample: [-2.0313244 -0.6405457 -0.9859198 -1.4080117 -1.6572207]
# Normas de gradientes: [np.float32(0.1650079), np.float32(0.10545885), np.float32(0.29931772), np.float32(0.057586093), np.float32(0.33619872), np.float32(0.059640646)]
# Memoria actual: 1324, Batch size: 64
# Recompensas batch - min: -5.645922660827637, max: 4.7015910148620605, mean: -0.7524309754371643
# Dones en batch: 0.0 de 64
# Targets sample: [-2.1147685 -1.0155652  1.5980122  1.2303233  2.7853267]
# Current Q values sample: [-2.402514   -1.5296427   0.32832494  1.6275676   1.7435873 ]
# Normas de gradientes: [np.float32(0.14271152), np.float32(0.08332115), np.float32(0.29914626), np.float32(0.06100364), np.float32(0.34431848), np.float32(0.05385181)]
# Memoria actual: 1328, Batch size: 64
# Recompensas batch - min: -100.0, max: 15.31848430633545, mean: -1.5535749197006226
# Dones en batch: 1.0 de 64
# Targets sample: [-1.5894139 -0.6963974 -2.1405141 -3.0013409 -0.6998763]
# Current Q values sample: [-1.6773403 -0.8339647 -1.9867867 -2.161862  -1.5977904]
# Normas de gradientes: [np.float32(0.26273045), np.float32(0.16866477), np.float32(0.5559329), np.float32(0.13340992), np.float32(0.6602975), np.float32(0.1519153)]
# Memoria actual: 1332, Batch size: 64
# Recompensas batch - min: -6.047372817993164, max: 7.60544490814209, mean: -0.5362582206726074
# Dones en batch: 0.0 de 64
# Targets sample: [-0.9843542 -2.4136016  0.7163356 -3.256272  -0.9552369]
# Current Q values sample: [-2.636013   -2.1779132  -0.45953885 -1.9606848  -0.90469486]
# Normas de gradientes: [np.float32(0.19539797), np.float32(0.11725305), np.float32(0.3792338), np.float32(0.07911481), np.float32(0.3948764), np.float32(0.06864014)]
# Memoria actual: 1336, Batch size: 64
# Recompensas batch - min: -3.6240320205688477, max: 7.346674919128418, mean: -0.6406631469726562
# Dones en batch: 0.0 de 64
# Targets sample: [-2.8733582 -2.3172913 -2.5294442 -0.6647072 -0.7459314]
# Current Q values sample: [-2.7894092 -1.7170966 -1.8616505 -1.2013004 -1.6282341]
# Normas de gradientes: [np.float32(0.13307282), np.float32(0.08863027), np.float32(0.35452285), np.float32(0.084644884), np.float32(0.444864), np.float32(0.086876646)]
# Memoria actual: 1340, Batch size: 64
# Recompensas batch - min: -100.0, max: 8.806502342224121, mean: -2.5445234775543213
# Dones en batch: 1.0 de 64
# Targets sample: [-2.6945677  -2.4305108  -0.30875233 -4.2584724  -2.1189387 ]
# Current Q values sample: [-2.1749015  -2.9866936  -0.29517707 -3.0236044  -1.7775047 ]
# Normas de gradientes: [np.float32(0.17021698), np.float32(0.08743604), np.float32(0.4196555), np.float32(0.08562725), np.float32(0.47692066), np.float32(0.08345)]
# Memoria actual: 1344, Batch size: 64
# Recompensas batch - min: -3.140956163406372, max: 106.64060974121094, mean: 1.2145823240280151
# Dones en batch: 0.0 de 64
# Targets sample: [-1.928099   -1.3326373  -0.17618406 -1.2290366  -1.4221938 ]
# Current Q values sample: [-2.1029582 -1.2180817 -0.5246846 -1.3333013 -1.5634367]
# Normas de gradientes: [np.float32(0.14402427), np.float32(0.10290937), np.float32(0.3541601), np.float32(0.09089649), np.float32(0.41446868), np.float32(0.090416215)]
# Memoria actual: 1348, Batch size: 64
# Recompensas batch - min: -3.3553223609924316, max: 3.4719486236572266, mean: -0.6568465232849121
# Dones en batch: 0.0 de 64
# Targets sample: [-0.6963974 -2.112143  -1.9722157 -1.8198613 -2.27878  ]
# Current Q values sample: [-0.8134248 -1.2494735 -1.54406   -2.7837696 -2.188322 ]
# Normas de gradientes: [np.float32(0.1386444), np.float32(0.09287616), np.float32(0.33979937), np.float32(0.082965024), np.float32(0.35845104), np.float32(0.08079135)]
# Memoria actual: 1352, Batch size: 64
# Recompensas batch - min: -3.874148368835449, max: 7.346674919128418, mean: -0.8069504499435425
# Dones en batch: 0.0 de 64
# Targets sample: [-0.5799478  -1.8816956  -0.33366263 -2.1704366   0.8485624 ]
# Current Q values sample: [-1.2324917 -1.7475139  0.0129548 -2.1790304  1.5023885]
# Normas de gradientes: [np.float32(0.1376588), np.float32(0.0837714), np.float32(0.32787743), np.float32(0.07421282), np.float32(0.36323056), np.float32(0.0631525)]
# Memoria actual: 1356, Batch size: 64
# Recompensas batch - min: -100.0, max: 27.281818389892578, mean: -3.1655361652374268
# Dones en batch: 2.0 de 64
# Targets sample: [-1.5801497  -0.42132318 -2.25533    -1.278737    0.16907746]
# Current Q values sample: [-2.1568992 -0.5950241 -1.9823312 -1.487635  -1.3462744]
# Normas de gradientes: [np.float32(0.19873837), np.float32(0.12693118), np.float32(0.42386293), np.float32(0.10292801), np.float32(0.42691195), np.float32(0.08643844)]
# Memoria actual: 1360, Batch size: 64
# Recompensas batch - min: -4.833984851837158, max: 6.137147903442383, mean: -0.6263810396194458
# Dones en batch: 0.0 de 64
# Targets sample: [-2.889756   1.1498898 -3.256935  -2.7699504 -2.4839418]
# Current Q values sample: [-3.1531405  0.4427824 -2.090113  -1.753021  -2.2220857]
# Normas de gradientes: [np.float32(0.15643226), np.float32(0.09674635), np.float32(0.3132737), np.float32(0.054613188), np.float32(0.28173104), np.float32(0.039887518)]
# Memoria actual: 1364, Batch size: 64
# Recompensas batch - min: -3.680156707763672, max: 5.534492015838623, mean: -0.6454816460609436
# Dones en batch: 0.0 de 64
# Targets sample: [-1.0588349   0.95688444 -1.618989   -3.7322125  -2.2728586 ]
# Current Q values sample: [-0.8086515 -1.3266381  0.2691398 -3.0182061 -1.697114 ]
# Normas de gradientes: [np.float32(0.112658136), np.float32(0.056394923), np.float32(0.28983366), np.float32(0.051282458), np.float32(0.29029694), np.float32(0.03400175)]
# Memoria actual: 1368, Batch size: 64
# Recompensas batch - min: -6.047372817993164, max: 106.64060974121094, mean: 0.8841341733932495
# Dones en batch: 0.0 de 64
# Targets sample: [-6.159912   -1.2890663  -1.4021751  -2.889756    0.27026793]
# Current Q values sample: [-1.1358616 -0.385051  -2.0972977 -3.1615798  0.1592378]
# Normas de gradientes: [np.float32(0.15642445), np.float32(0.08274714), np.float32(0.3564369), np.float32(0.06156993), np.float32(0.4072817), np.float32(0.063898884)]
# Memoria actual: 1372, Batch size: 64
# Recompensas batch - min: -6.386390209197998, max: 104.51860809326172, mean: 0.5340384244918823
# Dones en batch: 0.0 de 64
# Targets sample: [-3.2369308   0.0228886  -3.216033   -0.97038347 -1.4576906 ]
# Current Q values sample: [-3.2592607  -0.81474805 -2.1825604  -0.3529246  -1.3500235 ]
# Normas de gradientes: [np.float32(0.16821897), np.float32(0.11246055), np.float32(0.41784477), np.float32(0.0983543), np.float32(0.38479438), np.float32(0.070516974)]
# Memoria actual: 1376, Batch size: 64
# Recompensas batch - min: -3.202561378479004, max: 104.51860809326172, mean: 1.2126425504684448
# Dones en batch: 0.0 de 64
# Targets sample: [ 0.43325365 -1.5645001   1.2336667  -3.341866   -2.1650395 ]
# Current Q values sample: [-0.60531527 -0.59496784  1.1398816  -3.924391   -2.4018545 ]
# Normas de gradientes: [np.float32(0.18609898), np.float32(0.1276012), np.float32(0.45776534), np.float32(0.11564806), np.float32(0.5198635), np.float32(0.11341846)]
# Memoria actual: 1380, Batch size: 64
# Recompensas batch - min: -6.543637752532959, max: 15.31848430633545, mean: -0.7601807713508606
# Dones en batch: 0.0 de 64
# Targets sample: [ 0.819579   -1.9050136  -0.25864536 -1.543918   -0.42798978]
# Current Q values sample: [-0.18550077 -1.5023389  -1.4918029  -1.570925   -1.0004079 ]
# ...
# Memoria actual: 3604, Batch size: 64
# Recompensas batch - min: -100.0, max: 4.864133834838867, mean: -3.9807193279266357
# Dones en batch: 2.0 de 64
# Targets sample: [-2.1034672  4.9211683 -3.536236   0.4117906  5.566605 ]
# Current Q values sample: [-2.45717    4.809904  -3.9744823  0.7520427  4.8751197]
# Normas de gradientes: [np.float32(0.44987753), np.float32(0.19124687), np.float32(0.6080548), np.float32(0.096594), np.float32(0.7260568), np.float32(0.05940714)]
# Memoria actual: 3608, Batch size: 64
# Recompensas batch - min: -100.0, max: 4.131576061248779, mean: -3.5093183517456055
# Dones en batch: 2.0 de 64
# Targets sample: [2.0808518 5.7850266 3.293289  3.6860907 1.8461466]
# Current Q values sample: [1.8382518 4.8744235 1.4037049 3.0569437 1.5607694]
# Normas de gradientes: [np.float32(0.5375903), np.float32(0.33328855), np.float32(0.6099297), np.float32(0.115050405), np.float32(0.70202786), np.float32(0.07220133)]
# Memoria actual: 3612, Batch size: 64
# Recompensas batch - min: -4.30543851852417, max: 6.137147903442383, mean: -1.0383692979812622
# Dones en batch: 0.0 de 64
# Targets sample: [ 0.4571663  -0.48302394  4.9855056  -7.137541    1.2635145 ]
# Current Q values sample: [ 0.70082676 -0.64394623  4.657029   -7.460391    1.0689274 ]
# Normas de gradientes: [np.float32(0.376155), np.float32(0.22132225), np.float32(0.46238363), np.float32(0.07806643), np.float32(0.49547723), np.float32(0.038979445)]
# Memoria actual: 3616, Batch size: 64
# Recompensas batch - min: -100.0, max: 13.990330696105957, mean: -5.140326023101807
# Dones en batch: 3.0 de 64
# Targets sample: [-1.0206181 -3.7625294  2.2892804 12.0895405 -1.633388 ]
# Current Q values sample: [-2.5106819  -2.7361434   1.4505289  -0.42203432 -1.1753595 ]
# Normas de gradientes: [np.float32(0.79900444), np.float32(0.47575912), np.float32(0.99737334), np.float32(0.18421577), np.float32(1.0702771), np.float32(0.10687863)]
# Memoria actual: 3620, Batch size: 64
# Recompensas batch - min: -100.0, max: 12.526073455810547, mean: -3.7271409034729004
# Dones en batch: 2.0 de 64
# Targets sample: [  -2.385164   -100.            0.51499414   -4.724167     -2.760477  ]
# Current Q values sample: [-1.4314642  -8.653014    1.3192693  -0.09120198 -2.4576757 ]
# Normas de gradientes: [np.float32(0.81630915), np.float32(0.30800167), np.float32(0.90981334), np.float32(0.115812175), np.float32(1.0992547), np.float32(0.08114179)]
# Memoria actual: 3624, Batch size: 64
# Recompensas batch - min: -9.527741432189941, max: 97.10582733154297, mean: 0.6770268678665161
# Dones en batch: 0.0 de 64
# Targets sample: [ 7.1359377  3.0825105 -1.633388  -1.1754004  4.253305 ]
# Current Q values sample: [ 5.6066823  2.3674564 -1.164456  -1.4676672  4.2952504]
# Normas de gradientes: [np.float32(0.4536645), np.float32(0.2637856), np.float32(0.5847073), np.float32(0.10481988), np.float32(0.72273755), np.float32(0.060703754)]
# Memoria actual: 3628, Batch size: 64
# Recompensas batch - min: -7.391762733459473, max: 21.265439987182617, mean: 0.041960954666137695
# Dones en batch: 0.0 de 64
# Targets sample: [-0.4862191   2.9330835  -0.4904015   0.97270346  2.0430508 ]
# Current Q values sample: [ 1.4299712   1.3140357  -0.22400968  1.0077758   1.0328376 ]
# Normas de gradientes: [np.float32(0.4387602), np.float32(0.27567002), np.float32(0.6724142), np.float32(0.11020145), np.float32(0.7807861), np.float32(0.06266093)]
# Memoria actual: 3632, Batch size: 64
# Recompensas batch - min: -100.0, max: 10.967996597290039, mean: -3.780665159225464
# Dones en batch: 2.0 de 64
# Targets sample: [ 5.245448   -0.3505205  -0.12307048  4.2645965  -3.8712988 ]
# Current Q values sample: [ 0.1403439 -0.7284456 -0.5555997  3.8537564 -3.2186284]
# Normas de gradientes: [np.float32(0.6640523), np.float32(0.41505128), np.float32(0.64843565), np.float32(0.11824913), np.float32(0.657202), np.float32(0.04857258)]
# Memoria actual: 3636, Batch size: 64
# Recompensas batch - min: -100.0, max: 7.330549240112305, mean: -3.696967601776123
# Dones en batch: 2.0 de 64
# Targets sample: [-2.062186  -1.0625044  1.7271839  4.311851  -1.8448635]
# Current Q values sample: [-2.974465   -0.68615365  1.1806587   5.9488287  -1.4383323 ]
# Normas de gradientes: [np.float32(0.6060455), np.float32(0.3387375), np.float32(0.6283069), np.float32(0.08752161), np.float32(0.7114719), np.float32(0.033967834)]
# Memoria actual: 3640, Batch size: 64
# Recompensas batch - min: -4.731901168823242, max: 87.93480682373047, mean: 0.7126388549804688
# Dones en batch: 0.0 de 64
# Targets sample: [-0.78633296 -0.08646774  0.6269906  -9.717134    8.863142  ]
# Current Q values sample: [ -0.8205346   -0.16071138   0.9609252  -11.154897     7.0842505 ]
# Normas de gradientes: [np.float32(0.7660555), np.float32(0.49716267), np.float32(0.9126201), np.float32(0.15839213), np.float32(1.003939), np.float32(0.09625784)]
# Memoria actual: 3644, Batch size: 64
# Recompensas batch - min: -100.0, max: 6.379748344421387, mean: -2.387629508972168
# Dones en batch: 1.0 de 64
# Targets sample: [-4.0236692   6.5368133   3.0928402   8.863142    0.63566405]
# Current Q values sample: [-3.8086662  5.3609724  3.891472   7.0703855  1.1007267]
# Normas de gradientes: [np.float32(0.6493233), np.float32(0.4160033), np.float32(0.810461), np.float32(0.17864762), np.float32(0.836545), np.float32(0.105238594)]
# Memoria actual: 3648, Batch size: 64
# Recompensas batch - min: -100.0, max: 4.549930572509766, mean: -2.160792589187622
# Dones en batch: 1.0 de 64
# Targets sample: [-5.604766   -0.84986967 -5.8331285  -3.5850554  -1.4497771 ]
# Current Q values sample: [-6.5663795  -0.22460774 -5.1913824  -3.6085331  -2.4083667 ]
# Normas de gradientes: [np.float32(0.74022686), np.float32(0.46651718), np.float32(0.79824317), np.float32(0.1551116), np.float32(0.91106194), np.float32(0.09900558)]
# Memoria actual: 3652, Batch size: 64
# Recompensas batch - min: -100.0, max: 7.21357536315918, mean: -2.4679760932922363
# Dones en batch: 1.0 de 64
# Targets sample: [ 5.6277843  1.3062726  2.430468  -0.4904015  5.0962634]
# Current Q values sample: [ 4.523752   1.8286936  2.5138667 -0.3369555  5.05326  ]
# Normas de gradientes: [np.float32(0.6683436), np.float32(0.3411341), np.float32(0.8248204), np.float32(0.13439801), np.float32(0.83538914), np.float32(0.07328748)]
# Memoria actual: 3656, Batch size: 64
# Recompensas batch - min: -100.0, max: 9.56441879272461, mean: -2.785287857055664
# Dones en batch: 1.0 de 64
# Targets sample: [-2.6399713  -1.0480945  -0.90392077  2.1050766  -0.9179709 ]
# Current Q values sample: [-2.4018793  -1.1395444  -0.39682338  1.9924177  -0.9860385 ]
# Normas de gradientes: [np.float32(0.5016582), np.float32(0.30157602), np.float32(0.66400194), np.float32(0.114006795), np.float32(0.84278446), np.float32(0.074720226)]
# Memoria actual: 3660, Batch size: 64
# Recompensas batch - min: -100.0, max: 5.05746603012085, mean: -1.9623631238937378
# Dones en batch: 1.0 de 64
# Targets sample: [0.18593311 2.6660619  1.7605578  2.1596582  3.5387273 ]
# Current Q values sample: [-0.00871692  2.1890526   1.3036239   1.831621    3.0562615 ]
# Normas de gradientes: [np.float32(0.6493181), np.float32(0.4352092), np.float32(0.90378207), np.float32(0.17747635), np.float32(1.0925397), np.float32(0.11670075)]
# Memoria actual: 3664, Batch size: 64
# Recompensas batch - min: -100.0, max: 23.238956451416016, mean: -2.3643479347229004
# Dones en batch: 1.0 de 64
# Targets sample: [ 2.7595599 -6.7224984 -1.7645719  1.3200765 -4.2074575]
# Current Q values sample: [ 2.5603325 -7.1304655 -1.6126682  0.9664575 -4.128739 ]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14332\3119572855.py in ?()
#       1 agent = DQNAgent(lunar)
# ----> 2 agent.train()
#
# e:\Visual Studio\IA-2025-Modulo-lunar\DQN.py in ?(self)
#     297                 self.step_count += 1
#     298
#     299                 # Entrenar cada 4 pasos después del warmup
#     300                 if self.step_count > self.warmup_steps and self.step_count % 4 == 0:
# --> 301                     loss = self.update_model()
#     302                     episode_loss += loss
#     303
#     304             # Update target network con menos frecuencia
#
# e:\Visual Studio\IA-2025-Modulo-lunar\DQN.py in ?(self)
#     215
#     216         # Apply gradients
#     217         grads = tape.gradient(loss, self.q_network.trainable_variables)
#     218
# --> 219         grad_norms = [tf.norm(g).numpy() if g is not None else None for g in grads]
#     220         print(f"Normas de gradientes: {grad_norms}")
#     221
#     222         clipped_grads = [tf.clip_by_norm(grad, 1.0) if grad is not None else None for grad in grads]
#
# e:\Visual Studio\IA-2025-Modulo-lunar\DQN.py in ?(.0)
# --> 219     def update_model(self):
#     220         """
#     221         Perform experience replay to train the model.
#     222         Samples a batch of experiences from memory, computes target Q-values,
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\linalg_ops.py in ?(tensor, ord, axis, keepdims, name)
#     621     b) Explicitly supports 'euclidean' norm as the default, including for
#     622      higher order tensors.
#     623   @end_compatibility
#     624   """
# --> 625   return norm(tensor=tensor,
#     626               ord=ord,
#     627               axis=axis,
#     628               keepdims=keepdims,
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\deprecation.py in ?(*args, **kwargs)
#     584                 _call_location(), decorator_utils.get_qualified_name(func),
#     585                 func.__module__, arg_name,
#     586                 'in a future version' if date is None else ('after %s' % date),
#     587                 instructions)
# --> 588       return func(*args, **kwargs)
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\linalg_ops.py in ?(tensor, ord, axis, keepdims, name, keep_dims)
#     764         # this introduces a new op that is not supported in XLA, and breaks
#     765         # many existing TPU workloads (e.g. ResNet).
#     766         result = math_ops.sqrt(
#     767             math_ops.reduce_sum(
# --> 768                 tensor * math_ops.conj(tensor), axis, keepdims=True))
#     769     else:
#     770       result = math_ops.abs(tensor)
#     771       if ord == 1:
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\override_binary_operator.py in ?(x, y)
#     110         # TODO(b/178860388): Figure out why binary_op_wrapper and
#     111         #   r_binary_op_wrapper use different force_same_dtype values.
#     112         x, y = maybe_promote_tensors(x, y)
#     113         return func(x, y, name=name)
# --> 114       except (TypeError, ValueError) as e:
#     115         # Even if dispatching the op failed, the RHS may be a tensor aware
#     116         # object that can implement the operator with knowledge of itself
#     117         # and the tensor.
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\tensor_math_operator_overrides.py in ?(x, y, name)
#      61 def _mul_dispatch_factory(x, y, name=None):
#      62   from tensorflow.python.ops import math_ops
#      63
# ---> 64   return math_ops._mul_dispatch(x, y, name=name)  # pylint: disable=protected-access
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#    1723     new_vals = gen_sparse_ops.sparse_dense_cwise_mul(y.indices, y.values,
#    1724                                                      y.dense_shape, x, name)
#    1725     return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1726   else:
# -> 1727     return multiply(x, y, name=name)
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py in ?(*args, **kwargs)
#     140   def wrapper(*args, **kwargs):
#     141     if not ops.is_auto_dtype_conversion_enabled():
# --> 142       return op(*args, **kwargs)
#     143     bound_arguments = signature.bind(*args, **kwargs)
#     144     bound_arguments.apply_defaults()
#     145     bound_kwargs = bound_arguments.arguments
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#     522
#     523    * InvalidArgumentError: When `x` and `y` have incompatible shapes or types.
#     524   """
#     525
# --> 526   return gen_math_ops.mul(x, y, name)
#
# c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in ?(x, y, name)
#    7573         _ctx, "Mul", name, x, y)
#    7574       return _result
#    7575     except _core._NotOkStatusException as e:
#    7576       _ops.raise_from_not_ok_status(e, name)
# -> 7577     except _core._FallbackException:
#    7578       pass
#    7579     try:
#    7580       return mul_eager_fallback(
#
# KeyboardInterrupt:

# %% [markdown]
# Test

# %%
# agent with epsilon = 0.0 (no exploration)
agent = DQNAgent(lunar, epsilon=0.0)
agent.load_model("modelo_DQN.h5")
# Out:
# QNetwork:
#  <DQN name=dqn_2, built=True>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 # agent with epsilon = 0.0 (no exploration)
#       2 agent = DQNAgent(lunar, epsilon=0.0)
# ----> 3 agent.load_model("modelo_DQN.h5")
#
# File e:\Visual Studio\IA-2025-Modulo-lunar\DQN.py:240, in DQNAgent.load_model(self, path)
#     232 """
#     233 Load the model weights from a file.
#     234 Parameters:
#    (...)
#     237 None
#     238 """
#     239 # cargar el modelo desde el path indicado
# --> 240 self.q_network.load_weights(path)
#     241 self.update_target_network()
#
# File c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\h5py\_hl\files.py:564, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     555     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     556                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     557                      alignment_threshold=alignment_threshold,
#     558                      alignment_interval=alignment_interval,
#     559                      meta_block_size=meta_block_size,
#     560                      **kwds)
#     561     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     562                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     563                      fs_page_size=fs_page_size)
# --> 564     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     566 if isinstance(libver, tuple):
#     567     self._libver = libver
#
# File c:\Users\lolo1\AppData\Local\Programs\Python\Python310\lib\site-packages\h5py\_hl\files.py:238, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     236     if swmr and swmr_support:
#     237         flags |= h5f.ACC_SWMR_READ
# --> 238     fid = h5f.open(name, flags, fapl=fapl)
#     239 elif mode == 'r+':
#     240     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'modelo_DQN.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
test_lunar_lander(steps_to_run_before_pause=25, agent=agent, episodes=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 test_lunar_lander(steps_to_run_before_pause=25, agent=agent, episodes=1)
#
# NameError: name 'test_lunar_lander' is not defined

# %% [markdown]
# REINFORCE

# %%
from REINFORCE import REINFORCEAgent
lunar = LunarLanderEnv(render_mode=None)

# %%
# agent = REINFORCEAgent(lunar, episodes=5000)
# agent.load_model("modelo_REINFORCE.h5")

# %%
agent = REINFORCEAgent(lunar)
agent.load_model("modelo_REINFORCE.h5")

# %%
test_lunar_lander(steps_to_run_before_pause=75, agent=agent, episodes=1)
